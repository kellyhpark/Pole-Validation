# %% [markdown]
# # OPTIMIZING DETR

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### Objective
#
# Because the central aim of CERA is not only for pole validation, but setting the stage up for further hazard detection through images, the following notebook and code sets the groundwork. By optimizing the DETR object detection model on a custom image training set of 515 manually collected images of poles, the model will learn to identify poles in unfavorable conditions. These include time of day, lighting, angle, and close-ups.
#
# The following notebook should be run to replicate the training of the DETR model on our custom dataset of electric pole images and their corresponding annotations (COCO JSON files). Please run in Google Colab or on a PC with a GPU for best results.
#
# This fine-tuning references methods from the following Github Repo: https://github.com/woctezuma/finetune-detr

# %% [markdown]
# ### Data Description
#
# The training set used to optimize DETR in this notebook can be found in the `data` directory, under the `training` folder. The 515 images within it comprise of manually collected and labeled photos of electricity poles throughout La Jolla. These images were captured from the perspective of a member of the public who may have no domain knowledge of best object detection practices, or may have no capability to take quality pictures.
#
# Validation image set can be found in the `validation` directory also within the `data` folder of the repository.

# %% [markdown]
# ## 2. Setup

# %% [markdown]
# ### Feature Initialization & Library Imports
#
# Initialize the functions and variables required throughout the notebook to work with COCO JSON annotations and the DETR model.

# %%
# Import torch and ensure that CUDA is available. If not, please run on Google Colab
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

torch.set_grad_enabled(False);
# Out:
# 2.1.0+cu121 True

# %%
import torchvision.transforms as T
import matplotlib.pyplot as plt

# PyTorch image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Functions to process bounding boxes in image outputs
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
# Filter the bounding boxes that have low confidence with default threshold = 0.7
def filter_bboxes_from_outputs(outputs,threshold=0.7):

    # Retain predictions above the given threshold
    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > threshold

    probas_to_keep = probas[keep]

    # Scale bounding boxes
    bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)

    return probas_to_keep, bboxes_scaled

# %% [markdown]
# ### Clone DETR Branch
#
# Clone the following DETR [fork](https://github.com/woctezuma/detr/tree/finetune) which will allow for training on a custom dataset.

# %%
# ONLY run if running outside of Google Colab
# !mkdir -p content

# %%
# Run this cell regardless of server
# %cd /content/

# !rm -rf detr
# !git clone https://github.com/woctezuma/detr.git

# %cd detr/

# !git checkout finetune
# Out:
# /content
# Cloning into 'detr'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 263 (delta 4), reused 5 (delta 3), pack-reused 253
# Receiving objects: 100% (263/263), 324.61 KiB | 3.15 MiB/s, done.
# Resolving deltas: 100% (126/126), done.
# /content/detr
# Already on 'finetune'
# Your branch is up to date with 'origin/finetune'.

# %% [markdown]
# ### Initialize Pre-Trained Weights
#
# Load a pre-trained model checkpoint for DETR so that we can utilize the model without training it on a large dataset. This is particularly useful in light of fine-tuning the model.
#
# Different DETR checkpoint URL's can be found here:https://github.com/facebookresearch/detr#model-zoo

# %%
# Get pretrained weights
checkpoint = torch.hub.load_state_dict_from_url(
            url='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth',
            map_location='cpu',
            check_hash=True)

# Remove class weights
del checkpoint["model"]["class_embed.weight"]
del checkpoint["model"]["class_embed.bias"]

torch.save(checkpoint,
           'detr-r50_no-class-head.pth')
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth" to /root/.cache/torch/hub/checkpoints/detr-r50-e632da11.pth
# 100%|██████████| 159M/159M [00:01<00:00, 146MB/s]

# %% [markdown]
# ### Create Necessary Directories
#
# Run the following cell to create a series of needed directories.

# %%
# Create a series of directories for data to be stored
# !mkdir -p /content/data/structures/annotations/
# !mkdir -p /content/data/structures/train2017/
# !mkdir -p /content/data/structures/val2017/
# !mkdir -p /content/data/structures/valjpg/

# %% [markdown]
# In order for the DETR model to be trained, please now upload:
# - custom_train.json found in the annotation folder in the repo
# - custom_val.json found in the annotation folder in the repo
# - All training images found in the data/training folder in the repo
# - All validation images found in the data/validation folder in the repo
#
# The directory structure should reflect the following:
# ```
# path/to/coco/
# ├ annotations/  # JSON annotations
# │  ├ annotations/custom_train.json
# │  └ annotations/custom_val.json
# ├ train2017/    # training images
# ├ val2017/      # validation images
# └ valjpg/      # converted png to jpg images
# ```

# %% [markdown]
# PNG images are not compatible with output in the notebook. Thus, we must convert PNG images in the validation set to JPGs. These will be stored in the following folder: ```/content/data/structures/valjpg/ ```

# %%
from PIL import Image
import os
from os import listdir

# Convert the png validation images to jpg
directory = '/content/data/structures/val2017/'
new_directory = '/content/data/structures/valjpg/'

for image in os.listdir(directory):

    # Check if the image ends with PNG
    if (image.endswith(".PNG")):
        image_path = directory + image

        # Open image in PNG format
        img_png = Image.open(image_path)
        new_png = img_png.convert('RGB')

        #The image object is used to save the image in jpg format
        new_png.save(new_directory + image[:-4] + '_mod.jpg')

# %% [markdown]
# ### Load In and Demo Custom Data Set
#
# To ensure that the structure data has been loaded in correctly, we will display the annotations of randomly selected samples in the training set:
# -   Reference of COCO API Functionality: https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocoDemo.ipynb

# %%
# Select 0 or 1 to begin indexing image categories. We will begin with 1
first_class_index = 1

# %%
# Import necessary packages
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
# Initialize filepaths to the training data and train JSON
dataDir='/content/data/structures/'
dataType='train2017'
annFile='{}annotations/custom_train.json'.format(dataDir)

# %%
# Load the training JSON file through COCO
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
# Observe COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())

nms=[cat['name'] for cat in cats]
print('Categories: {}'.format(nms))

nms = set([cat['supercategory'] for cat in cats])
print('Super-categories: {}'.format(nms))
# Out:
# Categories: ['OH']
# Super-categories: {''}

# %% [markdown]
# Above, we observe that in our image labeling, there exists only one label category:
# - OH: Overhead Structures (poles)
#
# There exist no super-categories or overarching categories of structures.

# %%
# Load the image and category ID
catIds = coco.getCatIds(catNms=['OH']);
imgIds = coco.getImgIds(catIds=catIds );

# %%
# Choose a random image from the training set and display
img_id = imgIds[np.random.randint(0,len(imgIds))]
print('Image n°{}'.format(img_id))

img = coco.loadImgs(img_id)[0]

img_name = '%s/%s/%s'%(dataDir, dataType, img['file_name'])
print('Image name: {}'.format(img_name))

I = io.imread(img_name)
plt.figure()
plt.imshow(I)
# Out:
# Image n°450
# Image name: /content/data/structures//train2017/Frame 40.JPEG

# %%
# Obtain the annotations/label that correspond with this image
annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds)
anns = coco.loadAnns(annIds)

# Display the image with its bounding box(es)
plt.imshow(I)
coco.showAnns(anns, draw_bbox=True)

# %% [markdown]
# Above, we see a randomly selected image from our training set and bounding boxes around poles. These boxes are derived from our COCO JSON file, wherein boxes were manually bound for the purpose of training the DETR model.

# %% [markdown]
# ## 2. Fine-tuning DETR with Custom Data Set

# %%
assert(first_class_index in [0, 1])

if first_class_index == 0:
    # There is one class (OH) with ID n°1.
    num_classes = 1
    finetuned_classes = ['OH']

else:
    # DETR assumes that indexing starts with 0, so there is a dummy class with ID n°0.
    num_classes = 2
    finetuned_classes = ['N/A', 'OH']

print('First class index: {}'.format(first_class_index))
print('Parameter num_classes: {}'.format(num_classes))
print('Fine-tuned classes: {}'.format(finetuned_classes))
# Out:
# First class index: 1
# Parameter num_classes: 2
# Fine-tuned classes: ['N/A', 'OH']

# %%
# Enter detr directory
# %cd /content/detr/
# Out:
# /content/detr

# %% [markdown]
# Run the following cell to train the model on the training dataset on 10 epochs.

# %%
# Train the DETR model on our custom dataset
# !python main.py \
  --dataset_file "custom" \
  --coco_path "/content/data/structures/" \
  --output_dir "outputs" \
  --resume "detr-r50_no-class-head.pth" \
  --num_classes $num_classes \
  --epochs 10
# Out:
# Not using distributed mode
# git:
#   sha: e891373a8cab93d3719afb0acff28de94c6dc6a3, status: clean, branch: finetune
#
# Namespace(lr=0.0001, lr_backbone=1e-05, batch_size=2, weight_decay=0.0001, epochs=10, lr_drop=200, clip_max_norm=0.1, frozen_weights=None, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_queries=100, pre_norm=False, masks=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_giou=2, mask_loss_coef=1, dice_loss_coef=1, bbox_loss_coef=5, giou_loss_coef=2, eos_coef=0.1, num_classes=2, dataset_file='custom', coco_path='/content/data/structures/', coco_panoptic_path=None, remove_difficult=False, output_dir='outputs', device='cuda', seed=42, resume='detr-r50_no-class-head.pth', start_epoch=0, eval=False, num_workers=2, world_size=1, dist_url='env://', distributed=False)
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 172MB/s]
# number of params: 41279495
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Start training
# Epoch: [0]  [  0/257]  eta: 0:14:30  lr: 0.000100  class_error: 0.00  loss: 37.3918 (37.3918)  loss_ce: 1.6379 (1.6379)  loss_bbox: 2.6965 (2.6965)  loss_giou: 2.0601 (2.0601)  loss_ce_0: 1.5460 (1.5460)  loss_bbox_0: 2.2404 (2.2404)  loss_giou_0: 2.1022 (2.1022)  loss_ce_1: 1.5783 (1.5783)  loss_bbox_1: 2.7256 (2.7256)  loss_giou_1: 2.0360 (2.0360)  loss_ce_2: 1.6415 (1.6415)  loss_bbox_2: 2.4061 (2.4061)  loss_giou_2: 2.0591 (2.0591)  loss_ce_3: 1.6423 (1.6423)  loss_bbox_3: 2.5774 (2.5774)  loss_giou_3: 2.0677 (2.0677)  loss_ce_4: 1.6456 (1.6456)  loss_bbox_4: 2.6642 (2.6642)  loss_giou_4: 2.0652 (2.0652)  loss_ce_unscaled: 1.6379 (1.6379)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.5393 (0.5393)  loss_giou_unscaled: 1.0300 (1.0300)  cardinality_error_unscaled: 99.0000 (99.0000)  loss_ce_0_unscaled: 1.5460 (1.5460)  loss_bbox_0_unscaled: 0.4481 (0.4481)  loss_giou_0_unscaled: 1.0511 (1.0511)  cardinality_error_0_unscaled: 98.5000 (98.5000)  loss_ce_1_unscaled: 1.5783 (1.5783)  loss_bbox_1_unscaled: 0.5451 (0.5451)  loss_giou_1_unscaled: 1.0180 (1.0180)  cardinality_error_1_unscaled: 99.0000 (99.0000)  loss_ce_2_unscaled: 1.6415 (1.6415)  loss_bbox_2_unscaled: 0.4812 (0.4812)  loss_giou_2_unscaled: 1.0295 (1.0295)  cardinality_error_2_unscaled: 99.0000 (99.0000)  loss_ce_3_unscaled: 1.6423 (1.6423)  loss_bbox_3_unscaled: 0.5155 (0.5155)  loss_giou_3_unscaled: 1.0338 (1.0338)  cardinality_error_3_unscaled: 99.0000 (99.0000)  loss_ce_4_unscaled: 1.6456 (1.6456)  loss_bbox_4_unscaled: 0.5328 (0.5328)  loss_giou_4_unscaled: 1.0326 (1.0326)  cardinality_error_4_unscaled: 99.0000 (99.0000)  time: 3.3890  data: 0.3962  max mem: 1687
# Epoch: [0]  [ 10/257]  eta: 0:02:35  lr: 0.000100  class_error: 100.00  loss: 36.1737 (34.2393)  loss_ce: 0.9777 (1.0519)  loss_bbox: 2.6965 (2.7466)  loss_giou: 1.7817 (1.8009)  loss_ce_0: 1.2020 (1.2110)  loss_bbox_0: 2.4920 (2.6261)  loss_giou_0: 1.7980 (1.6924)  loss_ce_1: 1.1703 (1.2220)  loss_bbox_1: 2.7256 (2.9431)  loss_giou_1: 1.7243 (1.7377)  loss_ce_2: 1.1953 (1.2193)  loss_bbox_2: 2.6738 (2.8108)  loss_giou_2: 1.8670 (1.7780)  loss_ce_3: 1.1168 (1.1564)  loss_bbox_3: 2.6892 (2.7556)  loss_giou_3: 1.7864 (1.8099)  loss_ce_4: 1.0503 (1.1119)  loss_bbox_4: 2.6642 (2.7646)  loss_giou_4: 1.7782 (1.8011)  loss_ce_unscaled: 0.9777 (1.0519)  class_error_unscaled: 0.0000 (31.8182)  loss_bbox_unscaled: 0.5393 (0.5493)  loss_giou_unscaled: 0.8908 (0.9005)  cardinality_error_unscaled: 58.0000 (53.7727)  loss_ce_0_unscaled: 1.2020 (1.2110)  loss_bbox_0_unscaled: 0.4984 (0.5252)  loss_giou_0_unscaled: 0.8990 (0.8462)  cardinality_error_0_unscaled: 91.0000 (83.9091)  loss_ce_1_unscaled: 1.1703 (1.2220)  loss_bbox_1_unscaled: 0.5451 (0.5886)  loss_giou_1_unscaled: 0.8622 (0.8689)  cardinality_error_1_unscaled: 90.0000 (80.5455)  loss_ce_2_unscaled: 1.1953 (1.2193)  loss_bbox_2_unscaled: 0.5348 (0.5622)  loss_giou_2_unscaled: 0.9335 (0.8890)  cardinality_error_2_unscaled: 91.0000 (78.3636)  loss_ce_3_unscaled: 1.1168 (1.1564)  loss_bbox_3_unscaled: 0.5378 (0.5511)  loss_giou_3_unscaled: 0.8932 (0.9050)  cardinality_error_3_unscaled: 82.0000 (68.5455)  loss_ce_4_unscaled: 1.0503 (1.1119)  loss_bbox_4_unscaled: 0.5328 (0.5529)  loss_giou_4_unscaled: 0.8891 (0.9005)  cardinality_error_4_unscaled: 76.5000 (60.8182)  time: 0.6292  data: 0.0504  max mem: 2958
# Epoch: [0]  [ 20/257]  eta: 0:02:05  lr: 0.000100  class_error: 100.00  loss: 26.1560 (26.6637)  loss_ce: 0.5762 (0.7844)  loss_bbox: 1.6005 (2.0147)  loss_giou: 1.5484 (1.5420)  loss_ce_0: 0.8949 (0.9881)  loss_bbox_0: 1.4358 (1.8838)  loss_giou_0: 1.4617 (1.4285)  loss_ce_1: 0.8458 (0.9906)  loss_bbox_1: 1.7671 (2.1047)  loss_giou_1: 1.4375 (1.4612)  loss_ce_2: 0.8056 (0.9603)  loss_bbox_2: 1.3307 (2.0520)  loss_giou_2: 1.5285 (1.5505)  loss_ce_3: 0.7226 (0.8948)  loss_bbox_3: 1.6808 (1.9815)  loss_giou_3: 1.5583 (1.5792)  loss_ce_4: 0.6518 (0.8434)  loss_bbox_4: 1.6839 (2.0537)  loss_giou_4: 1.5642 (1.5503)  loss_ce_unscaled: 0.5762 (0.7844)  class_error_unscaled: 100.0000 (61.9048)  loss_bbox_unscaled: 0.3201 (0.4029)  loss_giou_unscaled: 0.7742 (0.7710)  cardinality_error_unscaled: 3.0000 (29.8095)  loss_ce_0_unscaled: 0.8949 (0.9881)  loss_bbox_0_unscaled: 0.2872 (0.3768)  loss_giou_0_unscaled: 0.7308 (0.7143)  cardinality_error_0_unscaled: 55.5000 (56.4048)  loss_ce_1_unscaled: 0.8458 (0.9906)  loss_bbox_1_unscaled: 0.3534 (0.4209)  loss_giou_1_unscaled: 0.7187 (0.7306)  cardinality_error_1_unscaled: 42.0000 (53.9762)  loss_ce_2_unscaled: 0.8056 (0.9603)  loss_bbox_2_unscaled: 0.2661 (0.4104)  loss_giou_2_unscaled: 0.7642 (0.7752)  cardinality_error_2_unscaled: 38.0000 (48.6905)  loss_ce_3_unscaled: 0.7226 (0.8948)  loss_bbox_3_unscaled: 0.3362 (0.3963)  loss_giou_3_unscaled: 0.7792 (0.7896)  cardinality_error_3_unscaled: 30.0000 (41.0476)  loss_ce_4_unscaled: 0.6518 (0.8434)  loss_bbox_4_unscaled: 0.3368 (0.4107)  loss_giou_4_unscaled: 0.7821 (0.7752)  cardinality_error_4_unscaled: 14.5000 (35.0476)  time: 0.3853  data: 0.0173  max mem: 3264
# Epoch: [0]  [ 30/257]  eta: 0:01:49  lr: 0.000100  class_error: 100.00  loss: 12.5690 (21.7933)  loss_ce: 0.4319 (0.6593)  loss_bbox: 0.5892 (1.5644)  loss_giou: 1.0169 (1.3213)  loss_ce_0: 0.6183 (0.8530)  loss_bbox_0: 0.7415 (1.4752)  loss_giou_0: 0.8632 (1.2101)  loss_ce_1: 0.6035 (0.8545)  loss_bbox_1: 0.6681 (1.6347)  loss_giou_1: 1.0143 (1.2586)  loss_ce_2: 0.5565 (0.8100)  loss_bbox_2: 0.6926 (1.6005)  loss_giou_2: 0.9248 (1.3198)  loss_ce_3: 0.5066 (0.7497)  loss_bbox_3: 0.6288 (1.5452)  loss_giou_3: 0.9550 (1.3336)  loss_ce_4: 0.4703 (0.7068)  loss_bbox_4: 0.6247 (1.5819)  loss_giou_4: 0.9887 (1.3148)  loss_ce_unscaled: 0.4319 (0.6593)  class_error_unscaled: 100.0000 (74.1935)  loss_bbox_unscaled: 0.1178 (0.3129)  loss_giou_unscaled: 0.5085 (0.6607)  cardinality_error_unscaled: 1.0000 (20.6129)  loss_ce_0_unscaled: 0.6183 (0.8530)  loss_bbox_0_unscaled: 0.1483 (0.2950)  loss_giou_0_unscaled: 0.4316 (0.6050)  cardinality_error_0_unscaled: 5.5000 (39.7903)  loss_ce_1_unscaled: 0.6035 (0.8545)  loss_bbox_1_unscaled: 0.1336 (0.3269)  loss_giou_1_unscaled: 0.5072 (0.6293)  cardinality_error_1_unscaled: 4.0000 (38.2903)  loss_ce_2_unscaled: 0.5565 (0.8100)  loss_bbox_2_unscaled: 0.1385 (0.3201)  loss_giou_2_unscaled: 0.4624 (0.6599)  cardinality_error_2_unscaled: 1.5000 (33.6935)  loss_ce_3_unscaled: 0.5066 (0.7497)  loss_bbox_3_unscaled: 0.1258 (0.3090)  loss_giou_3_unscaled: 0.4775 (0.6668)  cardinality_error_3_unscaled: 1.0000 (28.2258)  loss_ce_4_unscaled: 0.4703 (0.7068)  loss_bbox_4_unscaled: 0.1249 (0.3164)  loss_giou_4_unscaled: 0.4944 (0.6574)  cardinality_error_4_unscaled: 1.0000 (24.1613)  time: 0.3996  data: 0.0180  max mem: 3498
# Epoch: [0]  [ 40/257]  eta: 0:01:37  lr: 0.000100  class_error: 100.00  loss: 11.0328 (19.2461)  loss_ce: 0.3590 (0.5922)  loss_bbox: 0.4405 (1.3040)  loss_giou: 0.9602 (1.2402)  loss_ce_0: 0.4951 (0.7597)  loss_bbox_0: 0.5531 (1.2779)  loss_giou_0: 0.8540 (1.1403)  loss_ce_1: 0.4987 (0.7619)  loss_bbox_1: 0.5135 (1.3761)  loss_giou_1: 0.9750 (1.1687)  loss_ce_2: 0.4567 (0.7182)  loss_bbox_2: 0.4658 (1.3193)  loss_giou_2: 0.9101 (1.2127)  loss_ce_3: 0.4257 (0.6675)  loss_bbox_3: 0.4658 (1.2902)  loss_giou_3: 0.8863 (1.2365)  loss_ce_4: 0.3890 (0.6299)  loss_bbox_4: 0.4183 (1.3238)  loss_giou_4: 0.8614 (1.2271)  loss_ce_unscaled: 0.3590 (0.5922)  class_error_unscaled: 100.0000 (80.4878)  loss_bbox_unscaled: 0.0881 (0.2608)  loss_giou_unscaled: 0.4801 (0.6201)  cardinality_error_unscaled: 1.0000 (15.8902)  loss_ce_0_unscaled: 0.4951 (0.7597)  loss_bbox_0_unscaled: 0.1106 (0.2556)  loss_giou_0_unscaled: 0.4270 (0.5701)  cardinality_error_0_unscaled: 2.0000 (30.5000)  loss_ce_1_unscaled: 0.4987 (0.7619)  loss_bbox_1_unscaled: 0.1027 (0.2752)  loss_giou_1_unscaled: 0.4875 (0.5843)  cardinality_error_1_unscaled: 1.5000 (29.2561)  loss_ce_2_unscaled: 0.4567 (0.7182)  loss_bbox_2_unscaled: 0.0932 (0.2639)  loss_giou_2_unscaled: 0.4551 (0.6063)  cardinality_error_2_unscaled: 1.0000 (25.7805)  loss_ce_3_unscaled: 0.4257 (0.6675)  loss_bbox_3_unscaled: 0.0932 (0.2580)  loss_giou_3_unscaled: 0.4431 (0.6182)  cardinality_error_3_unscaled: 1.0000 (21.6463)  loss_ce_4_unscaled: 0.3890 (0.6299)  loss_bbox_4_unscaled: 0.0837 (0.2648)  loss_giou_4_unscaled: 0.4307 (0.6135)  cardinality_error_4_unscaled: 1.0000 (18.5732)  time: 0.3708  data: 0.0165  max mem: 3498
# Epoch: [0]  [ 50/257]  eta: 0:01:32  lr: 0.000100  class_error: 100.00  loss: 9.8807 (17.3167)  loss_ce: 0.3261 (0.5428)  loss_bbox: 0.4405 (1.1470)  loss_giou: 0.8106 (1.1384)  loss_ce_0: 0.4572 (0.6939)  loss_bbox_0: 0.5649 (1.1241)  loss_giou_0: 0.7987 (1.0502)  loss_ce_1: 0.4365 (0.6946)  loss_bbox_1: 0.4439 (1.2049)  loss_giou_1: 0.7692 (1.0633)  loss_ce_2: 0.3914 (0.6513)  loss_bbox_2: 0.4240 (1.1571)  loss_giou_2: 0.6794 (1.1091)  loss_ce_3: 0.3546 (0.6055)  loss_bbox_3: 0.4499 (1.1325)  loss_giou_3: 0.7671 (1.1359)  loss_ce_4: 0.3397 (0.5744)  loss_bbox_4: 0.4748 (1.1684)  loss_giou_4: 0.7694 (1.1233)  loss_ce_unscaled: 0.3261 (0.5428)  class_error_unscaled: 100.0000 (84.3137)  loss_bbox_unscaled: 0.0881 (0.2294)  loss_giou_unscaled: 0.4053 (0.5692)  cardinality_error_unscaled: 1.0000 (13.0000)  loss_ce_0_unscaled: 0.4572 (0.6939)  loss_bbox_0_unscaled: 0.1130 (0.2248)  loss_giou_0_unscaled: 0.3994 (0.5251)  cardinality_error_0_unscaled: 1.0000 (24.7451)  loss_ce_1_unscaled: 0.4365 (0.6946)  loss_bbox_1_unscaled: 0.0888 (0.2410)  loss_giou_1_unscaled: 0.3846 (0.5316)  cardinality_error_1_unscaled: 1.0000 (23.7451)  loss_ce_2_unscaled: 0.3914 (0.6513)  loss_bbox_2_unscaled: 0.0848 (0.2314)  loss_giou_2_unscaled: 0.3397 (0.5546)  cardinality_error_2_unscaled: 1.0000 (20.9510)  loss_ce_3_unscaled: 0.3546 (0.6055)  loss_bbox_3_unscaled: 0.0900 (0.2265)  loss_giou_3_unscaled: 0.3836 (0.5680)  cardinality_error_3_unscaled: 1.0000 (17.6275)  loss_ce_4_unscaled: 0.3397 (0.5744)  loss_bbox_4_unscaled: 0.0950 (0.2337)  loss_giou_4_unscaled: 0.3847 (0.5617)  cardinality_error_4_unscaled: 1.0000 (15.1569)  time: 0.3907  data: 0.0165  max mem: 3498
# Epoch: [0]  [ 60/257]  eta: 0:01:26  lr: 0.000100  class_error: 100.00  loss: 9.1537 (15.8768)  loss_ce: 0.3907 (0.5239)  loss_bbox: 0.3288 (1.0025)  loss_giou: 0.6321 (1.0639)  loss_ce_0: 0.4712 (0.6638)  loss_bbox_0: 0.3204 (0.9897)  loss_giou_0: 0.6978 (0.9964)  loss_ce_1: 0.4656 (0.6625)  loss_bbox_1: 0.3116 (1.0502)  loss_giou_1: 0.6559 (1.0008)  loss_ce_2: 0.4219 (0.6201)  loss_bbox_2: 0.2855 (1.0098)  loss_giou_2: 0.6481 (1.0420)  loss_ce_3: 0.3978 (0.5779)  loss_bbox_3: 0.2743 (0.9856)  loss_giou_3: 0.7182 (1.0695)  loss_ce_4: 0.3937 (0.5513)  loss_bbox_4: 0.2896 (1.0182)  loss_giou_4: 0.6100 (1.0486)  loss_ce_unscaled: 0.3907 (0.5239)  class_error_unscaled: 100.0000 (86.8852)  loss_bbox_unscaled: 0.0658 (0.2005)  loss_giou_unscaled: 0.3161 (0.5319)  cardinality_error_unscaled: 1.5000 (11.1393)  loss_ce_0_unscaled: 0.4712 (0.6638)  loss_bbox_0_unscaled: 0.0641 (0.1979)  loss_giou_0_unscaled: 0.3489 (0.4982)  cardinality_error_0_unscaled: 1.5000 (20.9098)  loss_ce_1_unscaled: 0.4656 (0.6625)  loss_bbox_1_unscaled: 0.0623 (0.2100)  loss_giou_1_unscaled: 0.3280 (0.5004)  cardinality_error_1_unscaled: 1.5000 (20.1066)  loss_ce_2_unscaled: 0.4219 (0.6201)  loss_bbox_2_unscaled: 0.0571 (0.2020)  loss_giou_2_unscaled: 0.3240 (0.5210)  cardinality_error_2_unscaled: 1.5000 (17.7869)  loss_ce_3_unscaled: 0.3978 (0.5779)  loss_bbox_3_unscaled: 0.0549 (0.1971)  loss_giou_3_unscaled: 0.3591 (0.5348)  cardinality_error_3_unscaled: 1.5000 (15.0082)  loss_ce_4_unscaled: 0.3937 (0.5513)  loss_bbox_4_unscaled: 0.0579 (0.2036)  loss_giou_4_unscaled: 0.3050 (0.5243)  cardinality_error_4_unscaled: 1.5000 (12.9426)  time: 0.4083  data: 0.0167  max mem: 3702
# Epoch: [0]  [ 70/257]  eta: 0:01:19  lr: 0.000100  class_error: 100.00  loss: 7.7169 (14.6020)  loss_ce: 0.3585 (0.4922)  loss_bbox: 0.2616 (0.8987)  loss_giou: 0.4882 (0.9812)  loss_ce_0: 0.4734 (0.6310)  loss_bbox_0: 0.2881 (0.8991)  loss_giou_0: 0.5238 (0.9273)  loss_ce_1: 0.4340 (0.6257)  loss_bbox_1: 0.2678 (0.9426)  loss_giou_1: 0.5018 (0.9219)  loss_ce_2: 0.3907 (0.5828)  loss_bbox_2: 0.2529 (0.9090)  loss_giou_2: 0.5240 (0.9643)  loss_ce_3: 0.3729 (0.5431)  loss_bbox_3: 0.2484 (0.8872)  loss_giou_3: 0.6831 (0.9944)  loss_ce_4: 0.3744 (0.5178)  loss_bbox_4: 0.2610 (0.9103)  loss_giou_4: 0.5459 (0.9734)  loss_ce_unscaled: 0.3585 (0.4922)  class_error_unscaled: 100.0000 (88.7324)  loss_bbox_unscaled: 0.0523 (0.1797)  loss_giou_unscaled: 0.2441 (0.4906)  cardinality_error_unscaled: 1.5000 (9.7254)  loss_ce_0_unscaled: 0.4734 (0.6310)  loss_bbox_0_unscaled: 0.0576 (0.1798)  loss_giou_0_unscaled: 0.2619 (0.4637)  cardinality_error_0_unscaled: 1.0000 (18.1127)  loss_ce_1_unscaled: 0.4340 (0.6257)  loss_bbox_1_unscaled: 0.0536 (0.1885)  loss_giou_1_unscaled: 0.2509 (0.4610)  cardinality_error_1_unscaled: 1.0000 (17.4225)  loss_ce_2_unscaled: 0.3907 (0.5828)  loss_bbox_2_unscaled: 0.0506 (0.1818)  loss_giou_2_unscaled: 0.2620 (0.4821)  cardinality_error_2_unscaled: 1.5000 (15.4366)  loss_ce_3_unscaled: 0.3729 (0.5431)  loss_bbox_3_unscaled: 0.0497 (0.1774)  loss_giou_3_unscaled: 0.3415 (0.4972)  cardinality_error_3_unscaled: 1.5000 (13.0423)  loss_ce_4_unscaled: 0.3744 (0.5178)  loss_bbox_4_unscaled: 0.0522 (0.1821)  loss_giou_4_unscaled: 0.2729 (0.4867)  cardinality_error_4_unscaled: 1.5000 (11.2676)  time: 0.3814  data: 0.0157  max mem: 4578
# Epoch: [0]  [ 80/257]  eta: 0:01:15  lr: 0.000100  class_error: 100.00  loss: 7.4029 (13.7939)  loss_ce: 0.2984 (0.4753)  loss_bbox: 0.3032 (0.8298)  loss_giou: 0.4620 (0.9323)  loss_ce_0: 0.4197 (0.6071)  loss_bbox_0: 0.2881 (0.8314)  loss_giou_0: 0.4758 (0.8853)  loss_ce_1: 0.4030 (0.6002)  loss_bbox_1: 0.3023 (0.8699)  loss_giou_1: 0.5030 (0.8843)  loss_ce_2: 0.3755 (0.5586)  loss_bbox_2: 0.3238 (0.8430)  loss_giou_2: 0.4538 (0.9184)  loss_ce_3: 0.3401 (0.5213)  loss_bbox_3: 0.3154 (0.8203)  loss_giou_3: 0.5545 (0.9485)  loss_ce_4: 0.3223 (0.4984)  loss_bbox_4: 0.2938 (0.8413)  loss_giou_4: 0.5292 (0.9285)  loss_ce_unscaled: 0.2984 (0.4753)  class_error_unscaled: 100.0000 (90.1235)  loss_bbox_unscaled: 0.0606 (0.1660)  loss_giou_unscaled: 0.2310 (0.4662)  cardinality_error_unscaled: 1.0000 (8.6852)  loss_ce_0_unscaled: 0.4197 (0.6071)  loss_bbox_0_unscaled: 0.0576 (0.1663)  loss_giou_0_unscaled: 0.2379 (0.4427)  cardinality_error_0_unscaled: 1.0000 (16.0062)  loss_ce_1_unscaled: 0.4030 (0.6002)  loss_bbox_1_unscaled: 0.0605 (0.1740)  loss_giou_1_unscaled: 0.2515 (0.4421)  cardinality_error_1_unscaled: 1.0000 (15.4259)  loss_ce_2_unscaled: 0.3755 (0.5586)  loss_bbox_2_unscaled: 0.0648 (0.1686)  loss_giou_2_unscaled: 0.2269 (0.4592)  cardinality_error_2_unscaled: 1.0000 (13.6914)  loss_ce_3_unscaled: 0.3401 (0.5213)  loss_bbox_3_unscaled: 0.0631 (0.1641)  loss_giou_3_unscaled: 0.2772 (0.4742)  cardinality_error_3_unscaled: 1.0000 (11.5864)  loss_ce_4_unscaled: 0.3223 (0.4984)  loss_bbox_4_unscaled: 0.0588 (0.1683)  loss_giou_4_unscaled: 0.2646 (0.4643)  cardinality_error_4_unscaled: 1.0000 (10.0370)  time: 0.3905  data: 0.0185  max mem: 4578
# Epoch: [0]  [ 90/257]  eta: 0:01:10  lr: 0.000100  class_error: 100.00  loss: 7.3919 (13.0668)  loss_ce: 0.3332 (0.4610)  loss_bbox: 0.2740 (0.7675)  loss_giou: 0.4748 (0.8980)  loss_ce_0: 0.4135 (0.5848)  loss_bbox_0: 0.2560 (0.7694)  loss_giou_0: 0.4815 (0.8501)  loss_ce_1: 0.3877 (0.5775)  loss_bbox_1: 0.3023 (0.8044)  loss_giou_1: 0.5285 (0.8465)  loss_ce_2: 0.3619 (0.5390)  loss_bbox_2: 0.2763 (0.7771)  loss_giou_2: 0.4835 (0.8740)  loss_ce_3: 0.3529 (0.5032)  loss_bbox_3: 0.2791 (0.7575)  loss_giou_3: 0.5497 (0.9048)  loss_ce_4: 0.3528 (0.4819)  loss_bbox_4: 0.2938 (0.7779)  loss_giou_4: 0.5292 (0.8924)  loss_ce_unscaled: 0.3332 (0.4610)  class_error_unscaled: 100.0000 (91.2088)  loss_bbox_unscaled: 0.0548 (0.1535)  loss_giou_unscaled: 0.2374 (0.4490)  cardinality_error_unscaled: 1.0000 (7.8681)  loss_ce_0_unscaled: 0.4135 (0.5848)  loss_bbox_0_unscaled: 0.0512 (0.1539)  loss_giou_0_unscaled: 0.2407 (0.4250)  cardinality_error_0_unscaled: 1.0000 (14.3626)  loss_ce_1_unscaled: 0.3877 (0.5775)  loss_bbox_1_unscaled: 0.0605 (0.1609)  loss_giou_1_unscaled: 0.2643 (0.4233)  cardinality_error_1_unscaled: 1.0000 (13.8626)  loss_ce_2_unscaled: 0.3619 (0.5390)  loss_bbox_2_unscaled: 0.0553 (0.1554)  loss_giou_2_unscaled: 0.2417 (0.4370)  cardinality_error_2_unscaled: 1.0000 (12.3242)  loss_ce_3_unscaled: 0.3529 (0.5032)  loss_bbox_3_unscaled: 0.0558 (0.1515)  loss_giou_3_unscaled: 0.2749 (0.4524)  cardinality_error_3_unscaled: 1.0000 (10.4505)  loss_ce_4_unscaled: 0.3528 (0.4819)  loss_bbox_4_unscaled: 0.0588 (0.1556)  loss_giou_4_unscaled: 0.2646 (0.4462)  cardinality_error_4_unscaled: 1.0000 (9.0714)  time: 0.4107  data: 0.0188  max mem: 5219
# Epoch: [0]  [100/257]  eta: 0:01:05  lr: 0.000100  class_error: 100.00  loss: 7.5821 (12.6580)  loss_ce: 0.3301 (0.4504)  loss_bbox: 0.2895 (0.7361)  loss_giou: 0.5932 (0.8781)  loss_ce_0: 0.3961 (0.5667)  loss_bbox_0: 0.3068 (0.7304)  loss_giou_0: 0.5364 (0.8322)  loss_ce_1: 0.3770 (0.5581)  loss_bbox_1: 0.2846 (0.7631)  loss_giou_1: 0.6092 (0.8349)  loss_ce_2: 0.3529 (0.5226)  loss_bbox_2: 0.2490 (0.7395)  loss_giou_2: 0.4835 (0.8554)  loss_ce_3: 0.3244 (0.4895)  loss_bbox_3: 0.2465 (0.7214)  loss_giou_3: 0.5497 (0.8886)  loss_ce_4: 0.3306 (0.4702)  loss_bbox_4: 0.2769 (0.7464)  loss_giou_4: 0.5500 (0.8744)  loss_ce_unscaled: 0.3301 (0.4504)  class_error_unscaled: 100.0000 (92.0792)  loss_bbox_unscaled: 0.0579 (0.1472)  loss_giou_unscaled: 0.2966 (0.4391)  cardinality_error_unscaled: 1.0000 (7.2129)  loss_ce_0_unscaled: 0.3961 (0.5667)  loss_bbox_0_unscaled: 0.0614 (0.1461)  loss_giou_0_unscaled: 0.2682 (0.4161)  cardinality_error_0_unscaled: 1.0000 (13.0644)  loss_ce_1_unscaled: 0.3770 (0.5581)  loss_bbox_1_unscaled: 0.0569 (0.1526)  loss_giou_1_unscaled: 0.3046 (0.4174)  cardinality_error_1_unscaled: 1.0000 (12.6139)  loss_ce_2_unscaled: 0.3529 (0.5226)  loss_bbox_2_unscaled: 0.0498 (0.1479)  loss_giou_2_unscaled: 0.2417 (0.4277)  cardinality_error_2_unscaled: 1.0000 (11.2277)  loss_ce_3_unscaled: 0.3244 (0.4895)  loss_bbox_3_unscaled: 0.0493 (0.1443)  loss_giou_3_unscaled: 0.2749 (0.4443)  cardinality_error_3_unscaled: 1.0000 (9.5396)  loss_ce_4_unscaled: 0.3306 (0.4702)  loss_bbox_4_unscaled: 0.0554 (0.1493)  loss_giou_4_unscaled: 0.2750 (0.4372)  cardinality_error_4_unscaled: 1.0000 (8.2970)  time: 0.3983  data: 0.0160  max mem: 5219
# Epoch: [0]  [110/257]  eta: 0:01:01  lr: 0.000100  class_error: 100.00  loss: 8.7495 (12.2867)  loss_ce: 0.3023 (0.4409)  loss_bbox: 0.3643 (0.7083)  loss_giou: 0.7195 (0.8580)  loss_ce_0: 0.3650 (0.5504)  loss_bbox_0: 0.3296 (0.7045)  loss_giou_0: 0.6962 (0.8212)  loss_ce_1: 0.3443 (0.5410)  loss_bbox_1: 0.3062 (0.7301)  loss_giou_1: 0.6507 (0.8231)  loss_ce_2: 0.3347 (0.5087)  loss_bbox_2: 0.3048 (0.7047)  loss_giou_2: 0.6585 (0.8338)  loss_ce_3: 0.3092 (0.4772)  loss_bbox_3: 0.3532 (0.6924)  loss_giou_3: 0.6552 (0.8642)  loss_ce_4: 0.3090 (0.4590)  loss_bbox_4: 0.3216 (0.7162)  loss_giou_4: 0.6396 (0.8529)  loss_ce_unscaled: 0.3023 (0.4409)  class_error_unscaled: 100.0000 (92.7928)  loss_bbox_unscaled: 0.0729 (0.1417)  loss_giou_unscaled: 0.3597 (0.4290)  cardinality_error_unscaled: 1.0000 (6.6802)  loss_ce_0_unscaled: 0.3650 (0.5504)  loss_bbox_0_unscaled: 0.0659 (0.1409)  loss_giou_0_unscaled: 0.3481 (0.4106)  cardinality_error_0_unscaled: 1.0000 (12.0045)  loss_ce_1_unscaled: 0.3443 (0.5410)  loss_bbox_1_unscaled: 0.0612 (0.1460)  loss_giou_1_unscaled: 0.3254 (0.4116)  cardinality_error_1_unscaled: 1.0000 (11.5946)  loss_ce_2_unscaled: 0.3347 (0.5087)  loss_bbox_2_unscaled: 0.0610 (0.1409)  loss_giou_2_unscaled: 0.3293 (0.4169)  cardinality_error_2_unscaled: 1.0000 (10.3333)  loss_ce_3_unscaled: 0.3092 (0.4772)  loss_bbox_3_unscaled: 0.0706 (0.1385)  loss_giou_3_unscaled: 0.3276 (0.4321)  cardinality_error_3_unscaled: 1.0000 (8.7973)  loss_ce_4_unscaled: 0.3090 (0.4590)  loss_bbox_4_unscaled: 0.0643 (0.1432)  loss_giou_4_unscaled: 0.3198 (0.4264)  cardinality_error_4_unscaled: 1.0000 (7.6667)  time: 0.3980  data: 0.0177  max mem: 5219
# Epoch: [0]  [120/257]  eta: 0:00:57  lr: 0.000100  class_error: 100.00  loss: 8.1363 (11.8249)  loss_ce: 0.2639 (0.4284)  loss_bbox: 0.3084 (0.6726)  loss_giou: 0.7195 (0.8272)  loss_ce_0: 0.3326 (0.5337)  loss_bbox_0: 0.3199 (0.6761)  loss_giou_0: 0.6244 (0.7992)  loss_ce_1: 0.3085 (0.5235)  loss_bbox_1: 0.3431 (0.6973)  loss_giou_1: 0.6268 (0.7978)  loss_ce_2: 0.2951 (0.4928)  loss_bbox_2: 0.2866 (0.6727)  loss_giou_2: 0.5779 (0.8053)  loss_ce_3: 0.2668 (0.4621)  loss_bbox_3: 0.3086 (0.6592)  loss_giou_3: 0.5918 (0.8319)  loss_ce_4: 0.2673 (0.4454)  loss_bbox_4: 0.2847 (0.6790)  loss_giou_4: 0.6136 (0.8210)  loss_ce_unscaled: 0.2639 (0.4284)  class_error_unscaled: 100.0000 (93.3884)  loss_bbox_unscaled: 0.0617 (0.1345)  loss_giou_unscaled: 0.3597 (0.4136)  cardinality_error_unscaled: 1.0000 (6.2273)  loss_ce_0_unscaled: 0.3326 (0.5337)  loss_bbox_0_unscaled: 0.0640 (0.1352)  loss_giou_0_unscaled: 0.3122 (0.3996)  cardinality_error_0_unscaled: 1.0000 (11.1074)  loss_ce_1_unscaled: 0.3085 (0.5235)  loss_bbox_1_unscaled: 0.0686 (0.1395)  loss_giou_1_unscaled: 0.3134 (0.3989)  cardinality_error_1_unscaled: 1.0000 (10.7355)  loss_ce_2_unscaled: 0.2951 (0.4928)  loss_bbox_2_unscaled: 0.0573 (0.1345)  loss_giou_2_unscaled: 0.2890 (0.4027)  cardinality_error_2_unscaled: 1.0000 (9.5785)  loss_ce_3_unscaled: 0.2668 (0.4621)  loss_bbox_3_unscaled: 0.0617 (0.1318)  loss_giou_3_unscaled: 0.2959 (0.4159)  cardinality_error_3_unscaled: 1.0000 (8.1694)  loss_ce_4_unscaled: 0.2673 (0.4454)  loss_bbox_4_unscaled: 0.0569 (0.1358)  loss_giou_4_unscaled: 0.3068 (0.4105)  cardinality_error_4_unscaled: 1.0000 (7.1322)  time: 0.3994  data: 0.0183  max mem: 5219
# Epoch: [0]  [130/257]  eta: 0:00:52  lr: 0.000100  class_error: 100.00  loss: 6.6295 (11.5202)  loss_ce: 0.2556 (0.4208)  loss_bbox: 0.2937 (0.6499)  loss_giou: 0.4738 (0.8095)  loss_ce_0: 0.3284 (0.5202)  loss_bbox_0: 0.3048 (0.6503)  loss_giou_0: 0.5263 (0.7894)  loss_ce_1: 0.3017 (0.5105)  loss_bbox_1: 0.3089 (0.6687)  loss_giou_1: 0.5632 (0.7836)  loss_ce_2: 0.2804 (0.4803)  loss_bbox_2: 0.2866 (0.6461)  loss_giou_2: 0.4366 (0.7890)  loss_ce_3: 0.2653 (0.4517)  loss_bbox_3: 0.2968 (0.6370)  loss_giou_3: 0.5174 (0.8158)  loss_ce_4: 0.2629 (0.4361)  loss_bbox_4: 0.2612 (0.6556)  loss_giou_4: 0.5308 (0.8058)  loss_ce_unscaled: 0.2556 (0.4208)  class_error_unscaled: 100.0000 (93.8931)  loss_bbox_unscaled: 0.0587 (0.1300)  loss_giou_unscaled: 0.2369 (0.4048)  cardinality_error_unscaled: 1.0000 (5.8588)  loss_ce_0_unscaled: 0.3284 (0.5202)  loss_bbox_0_unscaled: 0.0610 (0.1301)  loss_giou_0_unscaled: 0.2631 (0.3947)  cardinality_error_0_unscaled: 1.0000 (10.3664)  loss_ce_1_unscaled: 0.3017 (0.5105)  loss_bbox_1_unscaled: 0.0618 (0.1337)  loss_giou_1_unscaled: 0.2816 (0.3918)  cardinality_error_1_unscaled: 1.0000 (10.0229)  loss_ce_2_unscaled: 0.2804 (0.4803)  loss_bbox_2_unscaled: 0.0573 (0.1292)  loss_giou_2_unscaled: 0.2183 (0.3945)  cardinality_error_2_unscaled: 1.0000 (8.9542)  loss_ce_3_unscaled: 0.2653 (0.4517)  loss_bbox_3_unscaled: 0.0594 (0.1274)  loss_giou_3_unscaled: 0.2587 (0.4079)  cardinality_error_3_unscaled: 1.0000 (7.6450)  loss_ce_4_unscaled: 0.2629 (0.4361)  loss_bbox_4_unscaled: 0.0522 (0.1311)  loss_giou_4_unscaled: 0.2654 (0.4029)  cardinality_error_4_unscaled: 1.0000 (6.6947)  time: 0.3929  data: 0.0177  max mem: 5219
# Epoch: [0]  [140/257]  eta: 0:00:48  lr: 0.000100  class_error: 100.00  loss: 7.1285 (11.2649)  loss_ce: 0.2756 (0.4123)  loss_bbox: 0.2987 (0.6310)  loss_giou: 0.5030 (0.7955)  loss_ce_0: 0.3249 (0.5066)  loss_bbox_0: 0.3385 (0.6330)  loss_giou_0: 0.5263 (0.7789)  loss_ce_1: 0.2934 (0.4969)  loss_bbox_1: 0.3259 (0.6497)  loss_giou_1: 0.5503 (0.7717)  loss_ce_2: 0.2804 (0.4676)  loss_bbox_2: 0.3032 (0.6264)  loss_giou_2: 0.5108 (0.7764)  loss_ce_3: 0.2779 (0.4406)  loss_bbox_3: 0.2968 (0.6199)  loss_giou_3: 0.5762 (0.8020)  loss_ce_4: 0.2720 (0.4262)  loss_bbox_4: 0.2864 (0.6363)  loss_giou_4: 0.6283 (0.7938)  loss_ce_unscaled: 0.2756 (0.4123)  class_error_unscaled: 100.0000 (94.3262)  loss_bbox_unscaled: 0.0597 (0.1262)  loss_giou_unscaled: 0.2515 (0.3978)  cardinality_error_unscaled: 1.0000 (5.5284)  loss_ce_0_unscaled: 0.3249 (0.5066)  loss_bbox_0_unscaled: 0.0677 (0.1266)  loss_giou_0_unscaled: 0.2631 (0.3895)  cardinality_error_0_unscaled: 1.0000 (9.7092)  loss_ce_1_unscaled: 0.2934 (0.4969)  loss_bbox_1_unscaled: 0.0652 (0.1299)  loss_giou_1_unscaled: 0.2751 (0.3859)  cardinality_error_1_unscaled: 1.0000 (9.3972)  loss_ce_2_unscaled: 0.2804 (0.4676)  loss_bbox_2_unscaled: 0.0606 (0.1253)  loss_giou_2_unscaled: 0.2554 (0.3882)  cardinality_error_2_unscaled: 1.0000 (8.4043)  loss_ce_3_unscaled: 0.2779 (0.4406)  loss_bbox_3_unscaled: 0.0594 (0.1240)  loss_giou_3_unscaled: 0.2881 (0.4010)  cardinality_error_3_unscaled: 1.0000 (7.1879)  loss_ce_4_unscaled: 0.2720 (0.4262)  loss_bbox_4_unscaled: 0.0573 (0.1273)  loss_giou_4_unscaled: 0.3142 (0.3969)  cardinality_error_4_unscaled: 1.0000 (6.3050)  time: 0.3765  data: 0.0170  max mem: 5219
# Epoch: [0]  [150/257]  eta: 0:00:43  lr: 0.000100  class_error: 100.00  loss: 7.1285 (11.0066)  loss_ce: 0.2762 (0.4074)  loss_bbox: 0.2495 (0.6063)  loss_giou: 0.6275 (0.7824)  loss_ce_0: 0.3186 (0.4966)  loss_bbox_0: 0.3082 (0.6111)  loss_giou_0: 0.5684 (0.7688)  loss_ce_1: 0.2998 (0.4876)  loss_bbox_1: 0.2988 (0.6256)  loss_giou_1: 0.5503 (0.7629)  loss_ce_2: 0.2824 (0.4595)  loss_bbox_2: 0.2187 (0.6033)  loss_giou_2: 0.5108 (0.7636)  loss_ce_3: 0.2779 (0.4336)  loss_bbox_3: 0.2303 (0.5959)  loss_giou_3: 0.5762 (0.7904)  loss_ce_4: 0.2830 (0.4207)  loss_bbox_4: 0.2439 (0.6105)  loss_giou_4: 0.5806 (0.7803)  loss_ce_unscaled: 0.2762 (0.4074)  class_error_unscaled: 100.0000 (94.7020)  loss_bbox_unscaled: 0.0499 (0.1213)  loss_giou_unscaled: 0.3137 (0.3912)  cardinality_error_unscaled: 1.0000 (5.2550)  loss_ce_0_unscaled: 0.3186 (0.4966)  loss_bbox_0_unscaled: 0.0616 (0.1222)  loss_giou_0_unscaled: 0.2842 (0.3844)  cardinality_error_0_unscaled: 1.0000 (9.1589)  loss_ce_1_unscaled: 0.2998 (0.4876)  loss_bbox_1_unscaled: 0.0598 (0.1251)  loss_giou_1_unscaled: 0.2751 (0.3815)  cardinality_error_1_unscaled: 1.0000 (8.8675)  loss_ce_2_unscaled: 0.2824 (0.4595)  loss_bbox_2_unscaled: 0.0437 (0.1207)  loss_giou_2_unscaled: 0.2554 (0.3818)  cardinality_error_2_unscaled: 1.0000 (7.9404)  loss_ce_3_unscaled: 0.2779 (0.4336)  loss_bbox_3_unscaled: 0.0461 (0.1192)  loss_giou_3_unscaled: 0.2881 (0.3952)  cardinality_error_3_unscaled: 1.0000 (6.8046)  loss_ce_4_unscaled: 0.2830 (0.4207)  loss_bbox_4_unscaled: 0.0488 (0.1221)  loss_giou_4_unscaled: 0.2903 (0.3902)  cardinality_error_4_unscaled: 1.0000 (5.9801)  time: 0.3816  data: 0.0189  max mem: 5219
# Epoch: [0]  [160/257]  eta: 0:00:39  lr: 0.000100  class_error: 100.00  loss: 6.4722 (10.7424)  loss_ce: 0.3073 (0.4030)  loss_bbox: 0.2232 (0.5826)  loss_giou: 0.3988 (0.7638)  loss_ce_0: 0.3406 (0.4876)  loss_bbox_0: 0.2965 (0.5912)  loss_giou_0: 0.5684 (0.7576)  loss_ce_1: 0.3492 (0.4794)  loss_bbox_1: 0.2412 (0.6068)  loss_giou_1: 0.5806 (0.7493)  loss_ce_2: 0.3480 (0.4524)  loss_bbox_2: 0.2060 (0.5830)  loss_giou_2: 0.4569 (0.7455)  loss_ce_3: 0.3186 (0.4277)  loss_bbox_3: 0.1919 (0.5753)  loss_giou_3: 0.4182 (0.7708)  loss_ce_4: 0.3139 (0.4157)  loss_bbox_4: 0.2363 (0.5880)  loss_giou_4: 0.3959 (0.7627)  loss_ce_unscaled: 0.3073 (0.4030)  class_error_unscaled: 100.0000 (95.0311)  loss_bbox_unscaled: 0.0446 (0.1165)  loss_giou_unscaled: 0.1994 (0.3819)  cardinality_error_unscaled: 1.5000 (5.0155)  loss_ce_0_unscaled: 0.3406 (0.4876)  loss_bbox_0_unscaled: 0.0593 (0.1182)  loss_giou_0_unscaled: 0.2842 (0.3788)  cardinality_error_0_unscaled: 1.5000 (8.6770)  loss_ce_1_unscaled: 0.3492 (0.4794)  loss_bbox_1_unscaled: 0.0482 (0.1214)  loss_giou_1_unscaled: 0.2903 (0.3747)  cardinality_error_1_unscaled: 1.5000 (8.4037)  loss_ce_2_unscaled: 0.3480 (0.4524)  loss_bbox_2_unscaled: 0.0412 (0.1166)  loss_giou_2_unscaled: 0.2284 (0.3727)  cardinality_error_2_unscaled: 1.5000 (7.5342)  loss_ce_3_unscaled: 0.3186 (0.4277)  loss_bbox_3_unscaled: 0.0384 (0.1151)  loss_giou_3_unscaled: 0.2091 (0.3854)  cardinality_error_3_unscaled: 1.5000 (6.4689)  loss_ce_4_unscaled: 0.3139 (0.4157)  loss_bbox_4_unscaled: 0.0473 (0.1176)  loss_giou_4_unscaled: 0.1980 (0.3814)  cardinality_error_4_unscaled: 1.5000 (5.6957)  time: 0.3844  data: 0.0186  max mem: 5219
# Epoch: [0]  [170/257]  eta: 0:00:35  lr: 0.000100  class_error: 100.00  loss: 5.7030 (10.4823)  loss_ce: 0.2665 (0.3959)  loss_bbox: 0.2234 (0.5635)  loss_giou: 0.3681 (0.7463)  loss_ce_0: 0.3091 (0.4778)  loss_bbox_0: 0.3130 (0.5761)  loss_giou_0: 0.4810 (0.7478)  loss_ce_1: 0.2926 (0.4693)  loss_bbox_1: 0.2371 (0.5861)  loss_giou_1: 0.4173 (0.7330)  loss_ce_2: 0.2689 (0.4433)  loss_bbox_2: 0.2118 (0.5626)  loss_giou_2: 0.3569 (0.7291)  loss_ce_3: 0.2541 (0.4190)  loss_bbox_3: 0.2713 (0.5582)  loss_giou_3: 0.3434 (0.7551)  loss_ce_4: 0.2487 (0.4072)  loss_bbox_4: 0.2339 (0.5678)  loss_giou_4: 0.3635 (0.7444)  loss_ce_unscaled: 0.2665 (0.3959)  class_error_unscaled: 100.0000 (95.3216)  loss_bbox_unscaled: 0.0447 (0.1127)  loss_giou_unscaled: 0.1840 (0.3731)  cardinality_error_unscaled: 1.0000 (4.7865)  loss_ce_0_unscaled: 0.3091 (0.4778)  loss_bbox_0_unscaled: 0.0626 (0.1152)  loss_giou_0_unscaled: 0.2405 (0.3739)  cardinality_error_0_unscaled: 1.0000 (8.2281)  loss_ce_1_unscaled: 0.2926 (0.4693)  loss_bbox_1_unscaled: 0.0474 (0.1172)  loss_giou_1_unscaled: 0.2087 (0.3665)  cardinality_error_1_unscaled: 1.0000 (7.9795)  loss_ce_2_unscaled: 0.2689 (0.4433)  loss_bbox_2_unscaled: 0.0424 (0.1125)  loss_giou_2_unscaled: 0.1784 (0.3645)  cardinality_error_2_unscaled: 1.0000 (7.1579)  loss_ce_3_unscaled: 0.2541 (0.4190)  loss_bbox_3_unscaled: 0.0543 (0.1116)  loss_giou_3_unscaled: 0.1717 (0.3775)  cardinality_error_3_unscaled: 1.0000 (6.1579)  loss_ce_4_unscaled: 0.2487 (0.4072)  loss_bbox_4_unscaled: 0.0468 (0.1136)  loss_giou_4_unscaled: 0.1817 (0.3722)  cardinality_error_4_unscaled: 1.0000 (5.4269)  time: 0.3781  data: 0.0162  max mem: 5219
# Epoch: [0]  [180/257]  eta: 0:00:31  lr: 0.000100  class_error: 100.00  loss: 6.0269 (10.2698)  loss_ce: 0.2459 (0.3900)  loss_bbox: 0.2245 (0.5450)  loss_giou: 0.4540 (0.7340)  loss_ce_0: 0.2975 (0.4692)  loss_bbox_0: 0.2959 (0.5605)  loss_giou_0: 0.4954 (0.7335)  loss_ce_1: 0.2926 (0.4613)  loss_bbox_1: 0.2312 (0.5661)  loss_giou_1: 0.4039 (0.7172)  loss_ce_2: 0.2797 (0.4367)  loss_bbox_2: 0.2366 (0.5472)  loss_giou_2: 0.4042 (0.7198)  loss_ce_3: 0.2632 (0.4131)  loss_bbox_3: 0.2838 (0.5455)  loss_giou_3: 0.4735 (0.7480)  loss_ce_4: 0.2463 (0.4011)  loss_bbox_4: 0.2339 (0.5505)  loss_giou_4: 0.4331 (0.7310)  loss_ce_unscaled: 0.2459 (0.3900)  class_error_unscaled: 100.0000 (95.3039)  loss_bbox_unscaled: 0.0449 (0.1090)  loss_giou_unscaled: 0.2270 (0.3670)  cardinality_error_unscaled: 1.0000 (4.5829)  loss_ce_0_unscaled: 0.2975 (0.4692)  loss_bbox_0_unscaled: 0.0592 (0.1121)  loss_giou_0_unscaled: 0.2477 (0.3668)  cardinality_error_0_unscaled: 1.0000 (7.8425)  loss_ce_1_unscaled: 0.2926 (0.4613)  loss_bbox_1_unscaled: 0.0462 (0.1132)  loss_giou_1_unscaled: 0.2020 (0.3586)  cardinality_error_1_unscaled: 1.0000 (7.6022)  loss_ce_2_unscaled: 0.2797 (0.4367)  loss_bbox_2_unscaled: 0.0473 (0.1094)  loss_giou_2_unscaled: 0.2021 (0.3599)  cardinality_error_2_unscaled: 1.0000 (6.8867)  loss_ce_3_unscaled: 0.2632 (0.4131)  loss_bbox_3_unscaled: 0.0568 (0.1091)  loss_giou_3_unscaled: 0.2368 (0.3740)  cardinality_error_3_unscaled: 1.0000 (5.9227)  loss_ce_4_unscaled: 0.2463 (0.4011)  loss_bbox_4_unscaled: 0.0468 (0.1101)  loss_giou_4_unscaled: 0.2165 (0.3655)  cardinality_error_4_unscaled: 1.0000 (5.1878)  time: 0.4216  data: 0.0190  max mem: 5219
# Epoch: [0]  [190/257]  eta: 0:00:27  lr: 0.000100  class_error: 100.00  loss: 6.2348 (10.1042)  loss_ce: 0.2485 (0.3844)  loss_bbox: 0.2582 (0.5311)  loss_giou: 0.5011 (0.7300)  loss_ce_0: 0.2900 (0.4610)  loss_bbox_0: 0.2641 (0.5468)  loss_giou_0: 0.4954 (0.7246)  loss_ce_1: 0.2883 (0.4531)  loss_bbox_1: 0.2320 (0.5498)  loss_giou_1: 0.3756 (0.7045)  loss_ce_2: 0.3038 (0.4301)  loss_bbox_2: 0.2309 (0.5327)  loss_giou_2: 0.4254 (0.7104)  loss_ce_3: 0.2809 (0.4071)  loss_bbox_3: 0.3104 (0.5346)  loss_giou_3: 0.5465 (0.7464)  loss_ce_4: 0.2332 (0.3944)  loss_bbox_4: 0.2496 (0.5370)  loss_giou_4: 0.4851 (0.7262)  loss_ce_unscaled: 0.2485 (0.3844)  class_error_unscaled: 100.0000 (95.2880)  loss_bbox_unscaled: 0.0516 (0.1062)  loss_giou_unscaled: 0.2505 (0.3650)  cardinality_error_unscaled: 1.0000 (4.4110)  loss_ce_0_unscaled: 0.2900 (0.4610)  loss_bbox_0_unscaled: 0.0528 (0.1094)  loss_giou_0_unscaled: 0.2477 (0.3623)  cardinality_error_0_unscaled: 1.0000 (7.5052)  loss_ce_1_unscaled: 0.2883 (0.4531)  loss_bbox_1_unscaled: 0.0464 (0.1100)  loss_giou_1_unscaled: 0.1878 (0.3523)  cardinality_error_1_unscaled: 1.0000 (7.2696)  loss_ce_2_unscaled: 0.3038 (0.4301)  loss_bbox_2_unscaled: 0.0462 (0.1065)  loss_giou_2_unscaled: 0.2127 (0.3552)  cardinality_error_2_unscaled: 1.0000 (6.5864)  loss_ce_3_unscaled: 0.2809 (0.4071)  loss_bbox_3_unscaled: 0.0621 (0.1069)  loss_giou_3_unscaled: 0.2732 (0.3732)  cardinality_error_3_unscaled: 1.0000 (5.6754)  loss_ce_4_unscaled: 0.2332 (0.3944)  loss_bbox_4_unscaled: 0.0499 (0.1074)  loss_giou_4_unscaled: 0.2426 (0.3631)  cardinality_error_4_unscaled: 1.0000 (4.9843)  time: 0.4131  data: 0.0179  max mem: 5219
# Epoch: [0]  [200/257]  eta: 0:00:23  lr: 0.000100  class_error: 100.00  loss: 6.5066 (9.9580)  loss_ce: 0.2413 (0.3780)  loss_bbox: 0.2908 (0.5213)  loss_giou: 0.5011 (0.7228)  loss_ce_0: 0.3033 (0.4540)  loss_bbox_0: 0.2641 (0.5358)  loss_giou_0: 0.4855 (0.7162)  loss_ce_1: 0.2714 (0.4455)  loss_bbox_1: 0.2471 (0.5361)  loss_giou_1: 0.4688 (0.6949)  loss_ce_2: 0.2648 (0.4228)  loss_bbox_2: 0.2309 (0.5213)  loss_giou_2: 0.4254 (0.7032)  loss_ce_3: 0.2395 (0.3998)  loss_bbox_3: 0.3490 (0.5279)  loss_giou_3: 0.6223 (0.7434)  loss_ce_4: 0.2193 (0.3872)  loss_bbox_4: 0.3085 (0.5271)  loss_giou_4: 0.5235 (0.7207)  loss_ce_unscaled: 0.2413 (0.3780)  class_error_unscaled: 100.0000 (94.2786)  loss_bbox_unscaled: 0.0582 (0.1043)  loss_giou_unscaled: 0.2505 (0.3614)  cardinality_error_unscaled: 1.0000 (4.2438)  loss_ce_0_unscaled: 0.3033 (0.4540)  loss_bbox_0_unscaled: 0.0528 (0.1072)  loss_giou_0_unscaled: 0.2428 (0.3581)  cardinality_error_0_unscaled: 1.0000 (7.1915)  loss_ce_1_unscaled: 0.2714 (0.4455)  loss_bbox_1_unscaled: 0.0494 (0.1072)  loss_giou_1_unscaled: 0.2344 (0.3475)  cardinality_error_1_unscaled: 1.0000 (6.9627)  loss_ce_2_unscaled: 0.2648 (0.4228)  loss_bbox_2_unscaled: 0.0462 (0.1043)  loss_giou_2_unscaled: 0.2127 (0.3516)  cardinality_error_2_unscaled: 1.0000 (6.3134)  loss_ce_3_unscaled: 0.2395 (0.3998)  loss_bbox_3_unscaled: 0.0698 (0.1056)  loss_giou_3_unscaled: 0.3111 (0.3717)  cardinality_error_3_unscaled: 1.0000 (5.4453)  loss_ce_4_unscaled: 0.2193 (0.3872)  loss_bbox_4_unscaled: 0.0617 (0.1054)  loss_giou_4_unscaled: 0.2617 (0.3604)  cardinality_error_4_unscaled: 1.0000 (4.7910)  time: 0.3758  data: 0.0153  max mem: 5219
# Epoch: [0]  [210/257]  eta: 0:00:19  lr: 0.000100  class_error: 50.00  loss: 6.7920 (9.8415)  loss_ce: 0.2413 (0.3727)  loss_bbox: 0.2682 (0.5129)  loss_giou: 0.5893 (0.7195)  loss_ce_0: 0.3081 (0.4472)  loss_bbox_0: 0.2579 (0.5270)  loss_giou_0: 0.5422 (0.7121)  loss_ce_1: 0.2838 (0.4397)  loss_bbox_1: 0.2471 (0.5233)  loss_giou_1: 0.5227 (0.6874)  loss_ce_2: 0.2549 (0.4169)  loss_bbox_2: 0.2635 (0.5109)  loss_giou_2: 0.6460 (0.7021)  loss_ce_3: 0.2337 (0.3934)  loss_bbox_3: 0.2756 (0.5171)  loss_giou_3: 0.6223 (0.7400)  loss_ce_4: 0.2284 (0.3817)  loss_bbox_4: 0.3019 (0.5183)  loss_giou_4: 0.5578 (0.7193)  loss_ce_unscaled: 0.2413 (0.3727)  class_error_unscaled: 100.0000 (93.9179)  loss_bbox_unscaled: 0.0536 (0.1026)  loss_giou_unscaled: 0.2946 (0.3598)  cardinality_error_unscaled: 1.0000 (4.0900)  loss_ce_0_unscaled: 0.3081 (0.4472)  loss_bbox_0_unscaled: 0.0516 (0.1054)  loss_giou_0_unscaled: 0.2711 (0.3560)  cardinality_error_0_unscaled: 1.0000 (6.9147)  loss_ce_1_unscaled: 0.2838 (0.4397)  loss_bbox_1_unscaled: 0.0494 (0.1047)  loss_giou_1_unscaled: 0.2613 (0.3437)  cardinality_error_1_unscaled: 1.0000 (6.6943)  loss_ce_2_unscaled: 0.2549 (0.4169)  loss_bbox_2_unscaled: 0.0527 (0.1022)  loss_giou_2_unscaled: 0.3230 (0.3511)  cardinality_error_2_unscaled: 1.0000 (6.0664)  loss_ce_3_unscaled: 0.2337 (0.3934)  loss_bbox_3_unscaled: 0.0551 (0.1034)  loss_giou_3_unscaled: 0.3111 (0.3700)  cardinality_error_3_unscaled: 1.0000 (5.2370)  loss_ce_4_unscaled: 0.2284 (0.3817)  loss_bbox_4_unscaled: 0.0604 (0.1037)  loss_giou_4_unscaled: 0.2789 (0.3596)  cardinality_error_4_unscaled: 1.0000 (4.6090)  time: 0.4258  data: 0.0184  max mem: 5219
# Epoch: [0]  [220/257]  eta: 0:00:15  lr: 0.000100  class_error: 100.00  loss: 7.1604 (9.7803)  loss_ce: 0.2459 (0.3692)  loss_bbox: 0.2741 (0.5054)  loss_giou: 0.6978 (0.7223)  loss_ce_0: 0.3010 (0.4417)  loss_bbox_0: 0.2823 (0.5191)  loss_giou_0: 0.5641 (0.7128)  loss_ce_1: 0.2995 (0.4348)  loss_bbox_1: 0.2187 (0.5129)  loss_giou_1: 0.4831 (0.6845)  loss_ce_2: 0.2534 (0.4122)  loss_bbox_2: 0.2875 (0.5038)  loss_giou_2: 0.6728 (0.7046)  loss_ce_3: 0.2317 (0.3883)  loss_bbox_3: 0.2712 (0.5113)  loss_giou_3: 0.7077 (0.7436)  loss_ce_4: 0.2353 (0.3774)  loss_bbox_4: 0.3359 (0.5131)  loss_giou_4: 0.6376 (0.7234)  loss_ce_unscaled: 0.2459 (0.3692)  class_error_unscaled: 100.0000 (93.2881)  loss_bbox_unscaled: 0.0548 (0.1011)  loss_giou_unscaled: 0.3489 (0.3612)  cardinality_error_unscaled: 1.0000 (3.9593)  loss_ce_0_unscaled: 0.3010 (0.4417)  loss_bbox_0_unscaled: 0.0565 (0.1038)  loss_giou_0_unscaled: 0.2820 (0.3564)  cardinality_error_0_unscaled: 1.0000 (6.6584)  loss_ce_1_unscaled: 0.2995 (0.4348)  loss_bbox_1_unscaled: 0.0437 (0.1026)  loss_giou_1_unscaled: 0.2416 (0.3423)  cardinality_error_1_unscaled: 1.0000 (6.4480)  loss_ce_2_unscaled: 0.2534 (0.4122)  loss_bbox_2_unscaled: 0.0575 (0.1008)  loss_giou_2_unscaled: 0.3364 (0.3523)  cardinality_error_2_unscaled: 1.0000 (5.8507)  loss_ce_3_unscaled: 0.2317 (0.3883)  loss_bbox_3_unscaled: 0.0542 (0.1023)  loss_giou_3_unscaled: 0.3538 (0.3718)  cardinality_error_3_unscaled: 1.0000 (5.0452)  loss_ce_4_unscaled: 0.2353 (0.3774)  loss_bbox_4_unscaled: 0.0672 (0.1026)  loss_giou_4_unscaled: 0.3188 (0.3617)  cardinality_error_4_unscaled: 1.0000 (4.4548)  time: 0.4247  data: 0.0186  max mem: 5219
# Epoch: [0]  [230/257]  eta: 0:00:11  lr: 0.000100  class_error: 66.67  loss: 7.3413 (9.6704)  loss_ce: 0.2284 (0.3637)  loss_bbox: 0.2958 (0.4966)  loss_giou: 0.7023 (0.7201)  loss_ce_0: 0.2813 (0.4351)  loss_bbox_0: 0.2783 (0.5093)  loss_giou_0: 0.6125 (0.7104)  loss_ce_1: 0.2924 (0.4289)  loss_bbox_1: 0.2200 (0.5035)  loss_giou_1: 0.4921 (0.6804)  loss_ce_2: 0.2454 (0.4063)  loss_bbox_2: 0.2659 (0.4934)  loss_giou_2: 0.6728 (0.7020)  loss_ce_3: 0.2223 (0.3825)  loss_bbox_3: 0.3241 (0.5017)  loss_giou_3: 0.8058 (0.7429)  loss_ce_4: 0.2305 (0.3717)  loss_bbox_4: 0.3120 (0.5029)  loss_giou_4: 0.6454 (0.7190)  loss_ce_unscaled: 0.2284 (0.3637)  class_error_unscaled: 66.6667 (91.8831)  loss_bbox_unscaled: 0.0592 (0.0993)  loss_giou_unscaled: 0.3511 (0.3601)  cardinality_error_unscaled: 0.5000 (3.8333)  loss_ce_0_unscaled: 0.2813 (0.4351)  loss_bbox_0_unscaled: 0.0557 (0.1019)  loss_giou_0_unscaled: 0.3063 (0.3552)  cardinality_error_0_unscaled: 1.0000 (6.4156)  loss_ce_1_unscaled: 0.2924 (0.4289)  loss_bbox_1_unscaled: 0.0440 (0.1007)  loss_giou_1_unscaled: 0.2460 (0.3402)  cardinality_error_1_unscaled: 1.0000 (6.2143)  loss_ce_2_unscaled: 0.2454 (0.4063)  loss_bbox_2_unscaled: 0.0532 (0.0987)  loss_giou_2_unscaled: 0.3364 (0.3510)  cardinality_error_2_unscaled: 1.0000 (5.6364)  loss_ce_3_unscaled: 0.2223 (0.3825)  loss_bbox_3_unscaled: 0.0648 (0.1003)  loss_giou_3_unscaled: 0.4029 (0.3714)  cardinality_error_3_unscaled: 1.0000 (4.8680)  loss_ce_4_unscaled: 0.2305 (0.3717)  loss_bbox_4_unscaled: 0.0624 (0.1006)  loss_giou_4_unscaled: 0.3227 (0.3595)  cardinality_error_4_unscaled: 0.5000 (4.3030)  time: 0.3961  data: 0.0163  max mem: 5219
# Epoch: [0]  [240/257]  eta: 0:00:07  lr: 0.000100  class_error: 100.00  loss: 7.3076 (9.5787)  loss_ce: 0.2284 (0.3588)  loss_bbox: 0.3045 (0.4908)  loss_giou: 0.6202 (0.7160)  loss_ce_0: 0.2987 (0.4304)  loss_bbox_0: 0.2739 (0.5034)  loss_giou_0: 0.5143 (0.7030)  loss_ce_1: 0.2956 (0.4239)  loss_bbox_1: 0.2543 (0.4966)  loss_giou_1: 0.5479 (0.6752)  loss_ce_2: 0.2561 (0.4015)  loss_bbox_2: 0.2551 (0.4873)  loss_giou_2: 0.5822 (0.6956)  loss_ce_3: 0.2223 (0.3767)  loss_bbox_3: 0.3061 (0.4983)  loss_giou_3: 0.7495 (0.7408)  loss_ce_4: 0.2466 (0.3669)  loss_bbox_4: 0.2789 (0.4969)  loss_giou_4: 0.6192 (0.7165)  loss_ce_unscaled: 0.2284 (0.3588)  class_error_unscaled: 66.6667 (90.7676)  loss_bbox_unscaled: 0.0609 (0.0982)  loss_giou_unscaled: 0.3101 (0.3580)  cardinality_error_unscaled: 0.5000 (3.7137)  loss_ce_0_unscaled: 0.2987 (0.4304)  loss_bbox_0_unscaled: 0.0548 (0.1007)  loss_giou_0_unscaled: 0.2571 (0.3515)  cardinality_error_0_unscaled: 1.0000 (6.1971)  loss_ce_1_unscaled: 0.2956 (0.4239)  loss_bbox_1_unscaled: 0.0509 (0.0993)  loss_giou_1_unscaled: 0.2740 (0.3376)  cardinality_error_1_unscaled: 1.0000 (6.0000)  loss_ce_2_unscaled: 0.2561 (0.4015)  loss_bbox_2_unscaled: 0.0510 (0.0975)  loss_giou_2_unscaled: 0.2911 (0.3478)  cardinality_error_2_unscaled: 1.0000 (5.4461)  loss_ce_3_unscaled: 0.2223 (0.3767)  loss_bbox_3_unscaled: 0.0612 (0.0997)  loss_giou_3_unscaled: 0.3748 (0.3704)  cardinality_error_3_unscaled: 0.5000 (4.6950)  loss_ce_4_unscaled: 0.2466 (0.3669)  loss_bbox_4_unscaled: 0.0558 (0.0994)  loss_giou_4_unscaled: 0.3096 (0.3582)  cardinality_error_4_unscaled: 0.5000 (4.1598)  time: 0.4722  data: 0.0196  max mem: 5219
# Epoch: [0]  [250/257]  eta: 0:00:02  lr: 0.000100  class_error: 50.00  loss: 6.7836 (9.4246)  loss_ce: 0.2255 (0.3532)  loss_bbox: 0.2437 (0.4798)  loss_giou: 0.4580 (0.7075)  loss_ce_0: 0.3001 (0.4246)  loss_bbox_0: 0.2426 (0.4928)  loss_giou_0: 0.4373 (0.6947)  loss_ce_1: 0.2951 (0.4181)  loss_bbox_1: 0.2330 (0.4860)  loss_giou_1: 0.4918 (0.6672)  loss_ce_2: 0.2560 (0.3962)  loss_bbox_2: 0.2286 (0.4765)  loss_giou_2: 0.4513 (0.6877)  loss_ce_3: 0.2331 (0.3714)  loss_bbox_3: 0.2206 (0.4862)  loss_giou_3: 0.4771 (0.7295)  loss_ce_4: 0.2466 (0.3614)  loss_bbox_4: 0.2115 (0.4848)  loss_giou_4: 0.4049 (0.7070)  loss_ce_unscaled: 0.2255 (0.3532)  class_error_unscaled: 50.0000 (89.2430)  loss_bbox_unscaled: 0.0487 (0.0960)  loss_giou_unscaled: 0.2290 (0.3537)  cardinality_error_unscaled: 1.0000 (3.6195)  loss_ce_0_unscaled: 0.3001 (0.4246)  loss_bbox_0_unscaled: 0.0485 (0.0986)  loss_giou_0_unscaled: 0.2187 (0.3474)  cardinality_error_0_unscaled: 1.0000 (5.9900)  loss_ce_1_unscaled: 0.2951 (0.4181)  loss_bbox_1_unscaled: 0.0466 (0.0972)  loss_giou_1_unscaled: 0.2459 (0.3336)  cardinality_error_1_unscaled: 1.0000 (5.8048)  loss_ce_2_unscaled: 0.2560 (0.3962)  loss_bbox_2_unscaled: 0.0457 (0.0953)  loss_giou_2_unscaled: 0.2257 (0.3439)  cardinality_error_2_unscaled: 1.0000 (5.2629)  loss_ce_3_unscaled: 0.2331 (0.3714)  loss_bbox_3_unscaled: 0.0441 (0.0972)  loss_giou_3_unscaled: 0.2386 (0.3647)  cardinality_error_3_unscaled: 1.0000 (4.5538)  loss_ce_4_unscaled: 0.2466 (0.3614)  loss_bbox_4_unscaled: 0.0423 (0.0970)  loss_giou_4_unscaled: 0.2024 (0.3535)  cardinality_error_4_unscaled: 1.0000 (4.0478)  time: 0.4505  data: 0.0190  max mem: 5219
# Epoch: [0]  [256/257]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 5.9334 (9.3462)  loss_ce: 0.2298 (0.3509)  loss_bbox: 0.2213 (0.4765)  loss_giou: 0.4529 (0.7017)  loss_ce_0: 0.3001 (0.4216)  loss_bbox_0: 0.2420 (0.4887)  loss_giou_0: 0.4373 (0.6905)  loss_ce_1: 0.2956 (0.4150)  loss_bbox_1: 0.2212 (0.4807)  loss_giou_1: 0.4379 (0.6628)  loss_ce_2: 0.2497 (0.3934)  loss_bbox_2: 0.2149 (0.4703)  loss_giou_2: 0.3670 (0.6793)  loss_ce_3: 0.2355 (0.3684)  loss_bbox_3: 0.1883 (0.4815)  loss_giou_3: 0.3860 (0.7234)  loss_ce_4: 0.2406 (0.3594)  loss_bbox_4: 0.2115 (0.4815)  loss_giou_4: 0.4039 (0.7008)  loss_ce_unscaled: 0.2298 (0.3509)  class_error_unscaled: 50.0000 (88.3917)  loss_bbox_unscaled: 0.0443 (0.0953)  loss_giou_unscaled: 0.2265 (0.3508)  cardinality_error_unscaled: 1.0000 (3.5720)  loss_ce_0_unscaled: 0.3001 (0.4216)  loss_bbox_0_unscaled: 0.0484 (0.0977)  loss_giou_0_unscaled: 0.2187 (0.3452)  cardinality_error_0_unscaled: 1.0000 (5.8735)  loss_ce_1_unscaled: 0.2956 (0.4150)  loss_bbox_1_unscaled: 0.0442 (0.0961)  loss_giou_1_unscaled: 0.2190 (0.3314)  cardinality_error_1_unscaled: 1.0000 (5.6907)  loss_ce_2_unscaled: 0.2497 (0.3934)  loss_bbox_2_unscaled: 0.0430 (0.0941)  loss_giou_2_unscaled: 0.1835 (0.3397)  cardinality_error_2_unscaled: 1.0000 (5.1634)  loss_ce_3_unscaled: 0.2355 (0.3684)  loss_bbox_3_unscaled: 0.0377 (0.0963)  loss_giou_3_unscaled: 0.1930 (0.3617)  cardinality_error_3_unscaled: 1.0000 (4.4786)  loss_ce_4_unscaled: 0.2406 (0.3594)  loss_bbox_4_unscaled: 0.0423 (0.0963)  loss_giou_4_unscaled: 0.2019 (0.3504)  cardinality_error_4_unscaled: 1.0000 (3.9903)  time: 0.3932  data: 0.0147  max mem: 5219
# Epoch: [0] Total time: 0:01:45 (0.4113 s / it)
# ...
# Epoch: [9]  [230/257]  eta: 0:00:14  lr: 0.000100  class_error: 0.00  loss: 4.0848 (5.1578)  loss_ce: 0.0329 (0.0960)  loss_bbox: 0.1943 (0.2480)  loss_giou: 0.3455 (0.5005)  loss_ce_0: 0.0689 (0.1397)  loss_bbox_0: 0.2487 (0.2655)  loss_giou_0: 0.5313 (0.4953)  loss_ce_1: 0.0528 (0.1178)  loss_bbox_1: 0.2050 (0.2502)  loss_giou_1: 0.3901 (0.4878)  loss_ce_2: 0.0392 (0.0981)  loss_bbox_2: 0.1597 (0.2558)  loss_giou_2: 0.4070 (0.5205)  loss_ce_3: 0.0384 (0.0970)  loss_bbox_3: 0.2077 (0.2472)  loss_giou_3: 0.3742 (0.4982)  loss_ce_4: 0.0317 (0.0941)  loss_bbox_4: 0.1882 (0.2472)  loss_giou_4: 0.3416 (0.4989)  loss_ce_unscaled: 0.0329 (0.0960)  class_error_unscaled: 0.0000 (18.1385)  loss_bbox_unscaled: 0.0389 (0.0496)  loss_giou_unscaled: 0.1728 (0.2503)  cardinality_error_unscaled: 0.5000 (0.6623)  loss_ce_0_unscaled: 0.0689 (0.1397)  loss_bbox_0_unscaled: 0.0497 (0.0531)  loss_giou_0_unscaled: 0.2656 (0.2476)  cardinality_error_0_unscaled: 1.0000 (1.8420)  loss_ce_1_unscaled: 0.0528 (0.1178)  loss_bbox_1_unscaled: 0.0410 (0.0500)  loss_giou_1_unscaled: 0.1951 (0.2439)  cardinality_error_1_unscaled: 1.0000 (1.3225)  loss_ce_2_unscaled: 0.0392 (0.0981)  loss_bbox_2_unscaled: 0.0319 (0.0512)  loss_giou_2_unscaled: 0.2035 (0.2602)  cardinality_error_2_unscaled: 0.5000 (0.7879)  loss_ce_3_unscaled: 0.0384 (0.0970)  loss_bbox_3_unscaled: 0.0415 (0.0494)  loss_giou_3_unscaled: 0.1871 (0.2491)  cardinality_error_3_unscaled: 0.5000 (0.7273)  loss_ce_4_unscaled: 0.0317 (0.0941)  loss_bbox_4_unscaled: 0.0376 (0.0494)  loss_giou_4_unscaled: 0.1708 (0.2494)  cardinality_error_4_unscaled: 0.5000 (0.7316)  time: 0.5125  data: 0.0147  max mem: 5413
# Epoch: [9]  [240/257]  eta: 0:00:08  lr: 0.000100  class_error: 0.00  loss: 4.0848 (5.1456)  loss_ce: 0.0320 (0.0966)  loss_bbox: 0.1964 (0.2466)  loss_giou: 0.3858 (0.4994)  loss_ce_0: 0.0740 (0.1412)  loss_bbox_0: 0.2250 (0.2659)  loss_giou_0: 0.4825 (0.4935)  loss_ce_1: 0.0530 (0.1187)  loss_bbox_1: 0.2066 (0.2490)  loss_giou_1: 0.4072 (0.4878)  loss_ce_2: 0.0406 (0.0979)  loss_bbox_2: 0.1820 (0.2541)  loss_giou_2: 0.4070 (0.5184)  loss_ce_3: 0.0312 (0.0974)  loss_bbox_3: 0.2009 (0.2459)  loss_giou_3: 0.4118 (0.4965)  loss_ce_4: 0.0305 (0.0943)  loss_bbox_4: 0.1807 (0.2457)  loss_giou_4: 0.3804 (0.4968)  loss_ce_unscaled: 0.0320 (0.0966)  class_error_unscaled: 0.0000 (17.9095)  loss_bbox_unscaled: 0.0393 (0.0493)  loss_giou_unscaled: 0.1929 (0.2497)  cardinality_error_unscaled: 0.5000 (0.6598)  loss_ce_0_unscaled: 0.0740 (0.1412)  loss_bbox_0_unscaled: 0.0450 (0.0532)  loss_giou_0_unscaled: 0.2412 (0.2467)  cardinality_error_0_unscaled: 1.0000 (1.8216)  loss_ce_1_unscaled: 0.0530 (0.1187)  loss_bbox_1_unscaled: 0.0413 (0.0498)  loss_giou_1_unscaled: 0.2036 (0.2439)  cardinality_error_1_unscaled: 1.0000 (1.3154)  loss_ce_2_unscaled: 0.0406 (0.0979)  loss_bbox_2_unscaled: 0.0364 (0.0508)  loss_giou_2_unscaled: 0.2035 (0.2592)  cardinality_error_2_unscaled: 0.5000 (0.7884)  loss_ce_3_unscaled: 0.0312 (0.0974)  loss_bbox_3_unscaled: 0.0402 (0.0492)  loss_giou_3_unscaled: 0.2059 (0.2482)  cardinality_error_3_unscaled: 0.5000 (0.7241)  loss_ce_4_unscaled: 0.0305 (0.0943)  loss_bbox_4_unscaled: 0.0361 (0.0491)  loss_giou_4_unscaled: 0.1902 (0.2484)  cardinality_error_4_unscaled: 0.5000 (0.7282)  time: 0.5146  data: 0.0153  max mem: 5413
# Epoch: [9]  [250/257]  eta: 0:00:03  lr: 0.000100  class_error: 50.00  loss: 4.4999 (5.1390)  loss_ce: 0.0846 (0.0980)  loss_bbox: 0.2079 (0.2451)  loss_giou: 0.4223 (0.5004)  loss_ce_0: 0.1552 (0.1425)  loss_bbox_0: 0.2333 (0.2652)  loss_giou_0: 0.4191 (0.4936)  loss_ce_1: 0.0895 (0.1199)  loss_bbox_1: 0.2142 (0.2483)  loss_giou_1: 0.4686 (0.4871)  loss_ce_2: 0.0825 (0.1000)  loss_bbox_2: 0.1948 (0.2512)  loss_giou_2: 0.3945 (0.5144)  loss_ce_3: 0.0874 (0.0996)  loss_bbox_3: 0.1996 (0.2436)  loss_giou_3: 0.4278 (0.4947)  loss_ce_4: 0.0806 (0.0961)  loss_bbox_4: 0.1806 (0.2432)  loss_giou_4: 0.4303 (0.4964)  loss_ce_unscaled: 0.0846 (0.0980)  class_error_unscaled: 0.0000 (18.2584)  loss_bbox_unscaled: 0.0416 (0.0490)  loss_giou_unscaled: 0.2111 (0.2502)  cardinality_error_unscaled: 0.5000 (0.6693)  loss_ce_0_unscaled: 0.1552 (0.1425)  loss_bbox_0_unscaled: 0.0467 (0.0530)  loss_giou_0_unscaled: 0.2096 (0.2468)  cardinality_error_0_unscaled: 1.5000 (1.8367)  loss_ce_1_unscaled: 0.0895 (0.1199)  loss_bbox_1_unscaled: 0.0428 (0.0497)  loss_giou_1_unscaled: 0.2343 (0.2435)  cardinality_error_1_unscaled: 1.0000 (1.3127)  loss_ce_2_unscaled: 0.0825 (0.1000)  loss_bbox_2_unscaled: 0.0390 (0.0502)  loss_giou_2_unscaled: 0.1972 (0.2572)  cardinality_error_2_unscaled: 0.5000 (0.7928)  loss_ce_3_unscaled: 0.0874 (0.0996)  loss_bbox_3_unscaled: 0.0399 (0.0487)  loss_giou_3_unscaled: 0.2139 (0.2473)  cardinality_error_3_unscaled: 0.5000 (0.7410)  loss_ce_4_unscaled: 0.0806 (0.0961)  loss_bbox_4_unscaled: 0.0361 (0.0486)  loss_giou_4_unscaled: 0.2152 (0.2482)  cardinality_error_4_unscaled: 0.5000 (0.7351)  time: 0.5098  data: 0.0153  max mem: 5413
# Epoch: [9]  [256/257]  eta: 0:00:00  lr: 0.000100  class_error: 0.00  loss: 4.4396 (5.1340)  loss_ce: 0.0794 (0.0972)  loss_bbox: 0.1940 (0.2450)  loss_giou: 0.4223 (0.5004)  loss_ce_0: 0.0905 (0.1411)  loss_bbox_0: 0.2298 (0.2651)  loss_giou_0: 0.4191 (0.4934)  loss_ce_1: 0.0683 (0.1185)  loss_bbox_1: 0.2186 (0.2496)  loss_giou_1: 0.4731 (0.4873)  loss_ce_2: 0.0825 (0.0992)  loss_bbox_2: 0.1948 (0.2516)  loss_giou_2: 0.3945 (0.5138)  loss_ce_3: 0.0730 (0.0980)  loss_bbox_3: 0.1996 (0.2443)  loss_giou_3: 0.4296 (0.4954)  loss_ce_4: 0.0698 (0.0946)  loss_bbox_4: 0.1771 (0.2430)  loss_giou_4: 0.4645 (0.4964)  loss_ce_unscaled: 0.0794 (0.0972)  class_error_unscaled: 0.0000 (18.0591)  loss_bbox_unscaled: 0.0388 (0.0490)  loss_giou_unscaled: 0.2111 (0.2502)  cardinality_error_unscaled: 0.5000 (0.6654)  loss_ce_0_unscaled: 0.0905 (0.1411)  loss_bbox_0_unscaled: 0.0460 (0.0530)  loss_giou_0_unscaled: 0.2096 (0.2467)  cardinality_error_0_unscaled: 2.0000 (1.8268)  loss_ce_1_unscaled: 0.0683 (0.1185)  loss_bbox_1_unscaled: 0.0437 (0.0499)  loss_giou_1_unscaled: 0.2366 (0.2437)  cardinality_error_1_unscaled: 1.0000 (1.2996)  loss_ce_2_unscaled: 0.0825 (0.0992)  loss_bbox_2_unscaled: 0.0390 (0.0503)  loss_giou_2_unscaled: 0.1972 (0.2569)  cardinality_error_2_unscaled: 1.0000 (0.7879)  loss_ce_3_unscaled: 0.0730 (0.0980)  loss_bbox_3_unscaled: 0.0399 (0.0489)  loss_giou_3_unscaled: 0.2148 (0.2477)  cardinality_error_3_unscaled: 1.0000 (0.7354)  loss_ce_4_unscaled: 0.0698 (0.0946)  loss_bbox_4_unscaled: 0.0354 (0.0486)  loss_giou_4_unscaled: 0.2323 (0.2482)  cardinality_error_4_unscaled: 0.5000 (0.7276)  time: 0.5115  data: 0.0150  max mem: 5413
# Epoch: [9] Total time: 0:02:13 (0.5185 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 4.4396 (5.1340)  loss_ce: 0.0794 (0.0972)  loss_bbox: 0.1940 (0.2450)  loss_giou: 0.4223 (0.5004)  loss_ce_0: 0.0905 (0.1411)  loss_bbox_0: 0.2298 (0.2651)  loss_giou_0: 0.4191 (0.4934)  loss_ce_1: 0.0683 (0.1185)  loss_bbox_1: 0.2186 (0.2496)  loss_giou_1: 0.4731 (0.4873)  loss_ce_2: 0.0825 (0.0992)  loss_bbox_2: 0.1948 (0.2516)  loss_giou_2: 0.3945 (0.5138)  loss_ce_3: 0.0730 (0.0980)  loss_bbox_3: 0.1996 (0.2443)  loss_giou_3: 0.4296 (0.4954)  loss_ce_4: 0.0698 (0.0946)  loss_bbox_4: 0.1771 (0.2430)  loss_giou_4: 0.4645 (0.4964)  loss_ce_unscaled: 0.0794 (0.0972)  class_error_unscaled: 0.0000 (18.0591)  loss_bbox_unscaled: 0.0388 (0.0490)  loss_giou_unscaled: 0.2111 (0.2502)  cardinality_error_unscaled: 0.5000 (0.6654)  loss_ce_0_unscaled: 0.0905 (0.1411)  loss_bbox_0_unscaled: 0.0460 (0.0530)  loss_giou_0_unscaled: 0.2096 (0.2467)  cardinality_error_0_unscaled: 2.0000 (1.8268)  loss_ce_1_unscaled: 0.0683 (0.1185)  loss_bbox_1_unscaled: 0.0437 (0.0499)  loss_giou_1_unscaled: 0.2366 (0.2437)  cardinality_error_1_unscaled: 1.0000 (1.2996)  loss_ce_2_unscaled: 0.0825 (0.0992)  loss_bbox_2_unscaled: 0.0390 (0.0503)  loss_giou_2_unscaled: 0.1972 (0.2569)  cardinality_error_2_unscaled: 1.0000 (0.7879)  loss_ce_3_unscaled: 0.0730 (0.0980)  loss_bbox_3_unscaled: 0.0399 (0.0489)  loss_giou_3_unscaled: 0.2148 (0.2477)  cardinality_error_3_unscaled: 1.0000 (0.7354)  loss_ce_4_unscaled: 0.0698 (0.0946)  loss_bbox_4_unscaled: 0.0354 (0.0486)  loss_giou_4_unscaled: 0.2323 (0.2482)  cardinality_error_4_unscaled: 0.5000 (0.7276)
# Test:  [ 0/18]  eta: 0:00:15  class_error: 0.00  loss: 5.4464 (5.4464)  loss_ce: 0.0512 (0.0512)  loss_bbox: 0.1986 (0.1986)  loss_giou: 0.6984 (0.6984)  loss_ce_0: 0.1490 (0.1490)  loss_bbox_0: 0.1685 (0.1685)  loss_giou_0: 0.5003 (0.5003)  loss_ce_1: 0.0413 (0.0413)  loss_bbox_1: 0.3310 (0.3310)  loss_giou_1: 0.6050 (0.6050)  loss_ce_2: 0.2484 (0.2484)  loss_bbox_2: 0.1882 (0.1882)  loss_giou_2: 0.4749 (0.4749)  loss_ce_3: 0.2037 (0.2037)  loss_bbox_3: 0.1637 (0.1637)  loss_giou_3: 0.4235 (0.4235)  loss_ce_4: 0.0443 (0.0443)  loss_bbox_4: 0.2339 (0.2339)  loss_giou_4: 0.7226 (0.7226)  loss_ce_unscaled: 0.0512 (0.0512)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0397 (0.0397)  loss_giou_unscaled: 0.3492 (0.3492)  cardinality_error_unscaled: 1.5000 (1.5000)  loss_ce_0_unscaled: 0.1490 (0.1490)  loss_bbox_0_unscaled: 0.0337 (0.0337)  loss_giou_0_unscaled: 0.2501 (0.2501)  cardinality_error_0_unscaled: 2.0000 (2.0000)  loss_ce_1_unscaled: 0.0413 (0.0413)  loss_bbox_1_unscaled: 0.0662 (0.0662)  loss_giou_1_unscaled: 0.3025 (0.3025)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_2_unscaled: 0.2484 (0.2484)  loss_bbox_2_unscaled: 0.0376 (0.0376)  loss_giou_2_unscaled: 0.2374 (0.2374)  cardinality_error_2_unscaled: 0.5000 (0.5000)  loss_ce_3_unscaled: 0.2037 (0.2037)  loss_bbox_3_unscaled: 0.0327 (0.0327)  loss_giou_3_unscaled: 0.2118 (0.2118)  cardinality_error_3_unscaled: 1.5000 (1.5000)  loss_ce_4_unscaled: 0.0443 (0.0443)  loss_bbox_4_unscaled: 0.0468 (0.0468)  loss_giou_4_unscaled: 0.3613 (0.3613)  cardinality_error_4_unscaled: 1.0000 (1.0000)  time: 0.8498  data: 0.4146  max mem: 5413
# Test:  [10/18]  eta: 0:00:02  class_error: 0.00  loss: 4.0245 (5.5687)  loss_ce: 0.0512 (0.0624)  loss_bbox: 0.2272 (0.3174)  loss_giou: 0.5436 (0.6006)  loss_ce_0: 0.0672 (0.1065)  loss_bbox_0: 0.1944 (0.2593)  loss_giou_0: 0.4450 (0.4923)  loss_ce_1: 0.0572 (0.0884)  loss_bbox_1: 0.2418 (0.2967)  loss_giou_1: 0.4534 (0.5217)  loss_ce_2: 0.0443 (0.0605)  loss_bbox_2: 0.2622 (0.3390)  loss_giou_2: 0.4742 (0.5545)  loss_ce_3: 0.0585 (0.0844)  loss_bbox_3: 0.2019 (0.2780)  loss_giou_3: 0.4261 (0.5407)  loss_ce_4: 0.0443 (0.0596)  loss_bbox_4: 0.2362 (0.3097)  loss_giou_4: 0.4697 (0.5970)  loss_ce_unscaled: 0.0512 (0.0624)  class_error_unscaled: 0.0000 (4.5455)  loss_bbox_unscaled: 0.0454 (0.0635)  loss_giou_unscaled: 0.2718 (0.3003)  cardinality_error_unscaled: 0.5000 (0.9091)  loss_ce_0_unscaled: 0.0672 (0.1065)  loss_bbox_0_unscaled: 0.0389 (0.0519)  loss_giou_0_unscaled: 0.2225 (0.2462)  cardinality_error_0_unscaled: 1.0000 (1.1364)  loss_ce_1_unscaled: 0.0572 (0.0884)  loss_bbox_1_unscaled: 0.0484 (0.0593)  loss_giou_1_unscaled: 0.2267 (0.2608)  cardinality_error_1_unscaled: 1.0000 (0.7727)  loss_ce_2_unscaled: 0.0443 (0.0605)  loss_bbox_2_unscaled: 0.0524 (0.0678)  loss_giou_2_unscaled: 0.2371 (0.2773)  cardinality_error_2_unscaled: 0.5000 (0.5000)  loss_ce_3_unscaled: 0.0585 (0.0844)  loss_bbox_3_unscaled: 0.0404 (0.0556)  loss_giou_3_unscaled: 0.2131 (0.2703)  cardinality_error_3_unscaled: 1.0000 (1.0455)  loss_ce_4_unscaled: 0.0443 (0.0596)  loss_bbox_4_unscaled: 0.0472 (0.0619)  loss_giou_4_unscaled: 0.2349 (0.2985)  cardinality_error_4_unscaled: 0.5000 (0.7273)  time: 0.3451  data: 0.0599  max mem: 5413
# Test:  [17/18]  eta: 0:00:00  class_error: 0.00  loss: 3.8790 (4.7585)  loss_ce: 0.0399 (0.0712)  loss_bbox: 0.2056 (0.2671)  loss_giou: 0.4025 (0.4844)  loss_ce_0: 0.0690 (0.1138)  loss_bbox_0: 0.1685 (0.2281)  loss_giou_0: 0.3477 (0.4240)  loss_ce_1: 0.0572 (0.0802)  loss_bbox_1: 0.2146 (0.2566)  loss_giou_1: 0.3333 (0.4312)  loss_ce_2: 0.0322 (0.0778)  loss_bbox_2: 0.2545 (0.2878)  loss_giou_2: 0.3810 (0.4520)  loss_ce_3: 0.0545 (0.0788)  loss_bbox_3: 0.2019 (0.2469)  loss_giou_3: 0.3924 (0.4498)  loss_ce_4: 0.0370 (0.0679)  loss_bbox_4: 0.2339 (0.2618)  loss_giou_4: 0.4276 (0.4790)  loss_ce_unscaled: 0.0399 (0.0712)  class_error_unscaled: 0.0000 (13.8889)  loss_bbox_unscaled: 0.0411 (0.0534)  loss_giou_unscaled: 0.2013 (0.2422)  cardinality_error_unscaled: 0.5000 (0.7222)  loss_ce_0_unscaled: 0.0690 (0.1138)  loss_bbox_0_unscaled: 0.0337 (0.0456)  loss_giou_0_unscaled: 0.1738 (0.2120)  cardinality_error_0_unscaled: 1.0000 (0.9444)  loss_ce_1_unscaled: 0.0572 (0.0802)  loss_bbox_1_unscaled: 0.0429 (0.0513)  loss_giou_1_unscaled: 0.1667 (0.2156)  cardinality_error_1_unscaled: 0.5000 (0.5833)  loss_ce_2_unscaled: 0.0322 (0.0778)  loss_bbox_2_unscaled: 0.0509 (0.0576)  loss_giou_2_unscaled: 0.1905 (0.2260)  cardinality_error_2_unscaled: 0.5000 (0.4167)  loss_ce_3_unscaled: 0.0545 (0.0788)  loss_bbox_3_unscaled: 0.0404 (0.0494)  loss_giou_3_unscaled: 0.1962 (0.2249)  cardinality_error_3_unscaled: 1.0000 (0.9722)  loss_ce_4_unscaled: 0.0370 (0.0679)  loss_bbox_4_unscaled: 0.0468 (0.0524)  loss_giou_4_unscaled: 0.2138 (0.2395)  cardinality_error_4_unscaled: 0.5000 (0.6111)  time: 0.3057  data: 0.0434  max mem: 5413
# Test: Total time: 0:00:05 (0.3153 s / it)
# Averaged stats: class_error: 0.00  loss: 3.8790 (4.7585)  loss_ce: 0.0399 (0.0712)  loss_bbox: 0.2056 (0.2671)  loss_giou: 0.4025 (0.4844)  loss_ce_0: 0.0690 (0.1138)  loss_bbox_0: 0.1685 (0.2281)  loss_giou_0: 0.3477 (0.4240)  loss_ce_1: 0.0572 (0.0802)  loss_bbox_1: 0.2146 (0.2566)  loss_giou_1: 0.3333 (0.4312)  loss_ce_2: 0.0322 (0.0778)  loss_bbox_2: 0.2545 (0.2878)  loss_giou_2: 0.3810 (0.4520)  loss_ce_3: 0.0545 (0.0788)  loss_bbox_3: 0.2019 (0.2469)  loss_giou_3: 0.3924 (0.4498)  loss_ce_4: 0.0370 (0.0679)  loss_bbox_4: 0.2339 (0.2618)  loss_giou_4: 0.4276 (0.4790)  loss_ce_unscaled: 0.0399 (0.0712)  class_error_unscaled: 0.0000 (13.8889)  loss_bbox_unscaled: 0.0411 (0.0534)  loss_giou_unscaled: 0.2013 (0.2422)  cardinality_error_unscaled: 0.5000 (0.7222)  loss_ce_0_unscaled: 0.0690 (0.1138)  loss_bbox_0_unscaled: 0.0337 (0.0456)  loss_giou_0_unscaled: 0.1738 (0.2120)  cardinality_error_0_unscaled: 1.0000 (0.9444)  loss_ce_1_unscaled: 0.0572 (0.0802)  loss_bbox_1_unscaled: 0.0429 (0.0513)  loss_giou_1_unscaled: 0.1667 (0.2156)  cardinality_error_1_unscaled: 0.5000 (0.5833)  loss_ce_2_unscaled: 0.0322 (0.0778)  loss_bbox_2_unscaled: 0.0509 (0.0576)  loss_giou_2_unscaled: 0.1905 (0.2260)  cardinality_error_2_unscaled: 0.5000 (0.4167)  loss_ce_3_unscaled: 0.0545 (0.0788)  loss_bbox_3_unscaled: 0.0404 (0.0494)  loss_giou_3_unscaled: 0.1962 (0.2249)  cardinality_error_3_unscaled: 1.0000 (0.9722)  loss_ce_4_unscaled: 0.0370 (0.0679)  loss_bbox_4_unscaled: 0.0468 (0.0524)  loss_giou_4_unscaled: 0.2138 (0.2395)  cardinality_error_4_unscaled: 0.5000 (0.6111)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.406
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.774
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.343
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.406
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.651
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.651
# Training time 0:22:31

# %% [markdown]
# ## 3. Observation of Model Results

# %% [markdown]
# ### Training Results
#
# Reference: https://github.com/lessw2020/Thunder-Detr/blob/master/View_your_training_results.ipynb

# %%
# Import necessary packages
from util.plot_utils import plot_logs

from pathlib import Path

log_directory = [Path('outputs/')]

# %% [markdown]
# As mentioned in the code of [`plot_logs`](https://github.com/facebookresearch/detr/blob/5e66b4cd15b2b182da347103dd16578d28b49d69/util/plot_utils.py#L13):
# -   Solid lines in graphs indicate training results
# -   Dashed lines in graphs indicate validation results

# %%
# Plot the loss and mAP (mean average precision) over 10 epochs
fields_of_interest = (
    'loss',
    'mAP',
    )

plot_logs(log_directory,
          fields_of_interest)
# Out:
# /content/detr/util/plot_utils.py:65: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['test_coco_eval_bbox'], dtype='object')
#   df.interpolate().ewm(com=ewm_col).mean().plot(

# %%
# Plot the class error, bounding box, and GIOU (Generalized Intersection Over Union) losses
fields_of_interest = (
    'loss_ce',
    'loss_bbox',
    'loss_giou',
    )

plot_logs(log_directory,
          fields_of_interest)
# Out:
# /content/detr/util/plot_utils.py:65: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['test_coco_eval_bbox'], dtype='object')
#   df.interpolate().ewm(com=ewm_col).mean().plot(
# /content/detr/util/plot_utils.py:65: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['test_coco_eval_bbox'], dtype='object')
#   df.interpolate().ewm(com=ewm_col).mean().plot(
# /content/detr/util/plot_utils.py:65: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['test_coco_eval_bbox'], dtype='object')
#   df.interpolate().ewm(com=ewm_col).mean().plot(

# %%
# Plot the class error and cardinality error
fields_of_interest = (
    'class_error',
    'cardinality_error_unscaled',
    )

plot_logs(log_directory,
          fields_of_interest)
# Out:
# /content/detr/util/plot_utils.py:65: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['test_coco_eval_bbox'], dtype='object')
#   df.interpolate().ewm(com=ewm_col).mean().plot(
# /content/detr/util/plot_utils.py:65: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['test_coco_eval_bbox'], dtype='object')
#   df.interpolate().ewm(com=ewm_col).mean().plot(

# %% [markdown]
# ### Load the Fine-Tuned Model

# %%
# Load the fine-tuned model to display results
model = torch.hub.load('facebookresearch/detr',
                       'detr_resnet50',
                       pretrained=False,
                       num_classes=num_classes)

checkpoint = torch.load('outputs/checkpoint.pth',
                        map_location='cpu')

model.load_state_dict(checkpoint['model'],
                      strict=False)

model.eval();
# Out:
# Downloading: "https://github.com/facebookresearch/detr/zipball/main" to /root/.cache/torch/hub/main.zip
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### Display Fine-tuned Results

# %%
# Helper function to display results
def plot_finetuned_results(pil_img, img_name, prob=None, boxes=None):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    if prob is not None and boxes is not None:
        for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
            ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                    fill=False, color=c, linewidth=3))
            cl = p.argmax()
            text = f'{finetuned_classes[cl]}: {p[cl]:0.2f}'
            ax.text(xmin, ymin, text, fontsize=15,
                  bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.savefig(img_name)
    plt.show()

# %%
# Run the given image on the fine-tuned model
def run_worflow(my_image, my_model, img_name_root):
    # mean-std normalize the input image (batch-size: 1)
    img = transform(my_image).unsqueeze(0)

    # propagate through the model
    outputs = my_model(img)

    img_tag = 1
    for threshold in [0.9, 0.7]:
        probas_to_keep, bboxes_scaled = filter_bboxes_from_outputs(outputs,
                                                                threshold=threshold)
        img_name = img_name_root + str(img_tag) + ".png"
        plot_finetuned_results(my_image,img_name,
                              probas_to_keep,
                              bboxes_scaled)
        img_tag += 1

# %%
# Save model result images in "finetuned" directory
# !mkdir -p /content/data/structures/finetuned/

# %% [markdown]
# ### Display Training Image Results

# %%
# Colors for COCO visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# %%
# DETR results on randomly chosen training image
img_name = '/content/data/structures/train2017/IMG_1191.JPEG'
im = Image.open(img_name)

run_worflow(im,
            model, "/content/data/structures/finetuned/trial")

# %% [markdown]
# ### Display Validation Image Results

# %%
# Display validation results on set of 5 images
from glob import glob

val_images = glob('/content/data/structures/val2017/*.jpg')
img_root = "/content/data/structures/finetuned/val"
for i, img_name in enumerate(val_images):
    if i == 5:
        break
    im = Image.open(img_name)

    img_root = img_root + str(i)
    run_worflow(im,model, img_root)

# %%
# Display validation results on set of png turned jpg images
valjpg_images = glob('/content/data/structures/valjpg/*.jpg')
img_root = "/content/data/structures/finetuned/valid"
for i, img_name in enumerate(valjpg_images):
    if i == 5:
        break
    im = Image.open(img_name)

    img_root = img_root + str(i)
    run_worflow(im,model, img_root)

# %% [markdown]
# As seen in the images above, the DETR model, in each iteration of the image, presents further inspections of the image with its deductions on the target object within the photo. Accordingly, the number of bounding boxes increase as DETR inspects further with less confidence.
#
# For each bounding box, a label and DETR's confidence in the labeling are reflected next to the box. With each iteration of the results, the bounding boxes with lower confidence levels appear more frequently.
#
# We see that while the model does relatively well on poles that show the whole pole, it tends to confuse trees with poles, and has greater difficulty in identifying when the images of the pole are close-up. Yet, for the purposes of our Proof of Concept, the model is adequate and produces promising results.
